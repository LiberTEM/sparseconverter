# %%
import numpy as np
import cupy

import sparseconverter as spc

# %%
b = spc.benchmark_conversions(
    shape=(32, 512, 512),
    dtype=np.float32,
    density=0.1,
    backends=spc.BACKENDS
)
# Out:
# scipy.sparse.csr_matrix scipy.sparse.csr_matrix (1.5e-06, 2.33e-05, 1.559e-05)
# scipy.sparse.csr_matrix numpy.matrix (0.0110052, 0.0157332, 0.01296974)
# scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.0070688, 0.0078233, 0.00750969)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.0113602, 0.0154606, 0.01204903)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.0111631, 0.0121154, 0.01167255)
# scipy.sparse.csr_matrix sparse.GCXS (2.16e-05, 0.0001625, 0.00011317)
# scipy.sparse.csr_matrix cuda (0.0048354, 0.008049, 0.00557031)
# scipy.sparse.csr_matrix sparse.DOK (0.69527, 0.8421969, 0.76682186)
# scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.0091234, 0.0195501, 0.01089365)
# scipy.sparse.csr_matrix sparse.COO (0.0164134, 0.0172567, 0.01680042)
# scipy.sparse.csr_matrix cupy (0.0448152, 0.0543023, 0.04632367)
# scipy.sparse.csr_matrix numpy (0.0048379, 0.0051434, 0.00495233)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (0.0021677, 0.0046498, 0.00258754)
# numpy.matrix scipy.sparse.csr_matrix (0.0735788, 0.0907291, 0.07890904)
# numpy.matrix numpy.matrix (1.3e-06, 2.1e-05, 1.088e-05)
# numpy.matrix scipy.sparse.coo_matrix (0.0693304, 0.0905272, 0.07567136)
# numpy.matrix cupyx.scipy.sparse.coo_matrix (0.0274253, 0.0718463, 0.06118977)
# numpy.matrix cupyx.scipy.sparse.csc_matrix (0.0584258, 0.0753017, 0.06415718)
# numpy.matrix sparse.GCXS (0.0811718, 0.0986444, 0.08824788)
# numpy.matrix cuda (0.0051676, 0.0076107, 0.00578329)
# numpy.matrix sparse.DOK (0.3678304, 0.4381423, 0.40563613)
# numpy.matrix scipy.sparse.csc_matrix (0.0781644, 0.0958265, 0.08555071)
# numpy.matrix sparse.COO (0.0514923, 0.0729679, 0.0559763)
# numpy.matrix cupy (0.0091891, 0.0166621, 0.01035024)
# numpy.matrix numpy (0.0051074, 0.0056316, 0.00535645)
# numpy.matrix cupyx.scipy.sparse.csr_matrix (0.0545768, 0.0595071, 0.05678837)
# scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.0034227, 0.0056437, 0.00395482)
# scipy.sparse.coo_matrix numpy.matrix (0.0115775, 0.0224351, 0.0140713)
# scipy.sparse.coo_matrix scipy.sparse.coo_matrix (1.7e-06, 3.06e-05, 1.347e-05)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (0.0092604, 0.0099185, 0.00961638)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.0158484, 0.0286806, 0.01900467)
# scipy.sparse.coo_matrix sparse.GCXS (0.0033655, 0.0081335, 0.00433509)
# scipy.sparse.coo_matrix cuda (0.0048549, 0.0062049, 0.00515917)
# scipy.sparse.coo_matrix sparse.DOK (0.6817322, 0.7715689, 0.73489066)
# scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.0084794, 0.0164477, 0.0104346)
# scipy.sparse.coo_matrix sparse.COO (0.0014386, 0.0031913, 0.00170327)
# scipy.sparse.coo_matrix cupy (0.0913921, 0.1169521, 0.09446578)
# scipy.sparse.coo_matrix numpy (0.0047674, 0.0052122, 0.00495998)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.0089714, 0.0099174, 0.00931616)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.0473972, 0.0480378, 0.04777264)
# cupyx.scipy.sparse.coo_matrix numpy.matrix (0.0196348, 0.0231192, 0.02061129)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.coo_matrix (0.0062247, 0.0099869, 0.00705612)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (1.3e-06, 4.48e-05, 1.379e-05)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.0507979, 0.0716717, 0.05469087)
# cupyx.scipy.sparse.coo_matrix sparse.GCXS (0.0478066, 0.0779599, 0.0513449)
# cupyx.scipy.sparse.coo_matrix cuda (0.0114645, 0.0149943, 0.01209151)
# cupyx.scipy.sparse.coo_matrix sparse.DOK (0.7170884, 0.8448499, 0.77208511)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.0481854, 0.0528035, 0.0499516)
# cupyx.scipy.sparse.coo_matrix sparse.COO (0.0195236, 0.0289447, 0.02214925)
# cupyx.scipy.sparse.coo_matrix cupy (0.0823345, 0.1533947, 0.09027534)
# cupyx.scipy.sparse.coo_matrix numpy (0.0113334, 0.0144463, 0.01201211)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.0309912, 0.0477266, 0.03314292)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.0063299, 0.0073484, 0.00688394)
# cupyx.scipy.sparse.csc_matrix numpy.matrix (0.0668645, 0.0822671, 0.07303444)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.0109227, 0.0141537, 0.01199444)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.0050099, 0.0057794, 0.00533084)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (1.4e-06, 3.49e-05, 1.648e-05)
# cupyx.scipy.sparse.csc_matrix sparse.GCXS (0.0057041, 0.0108932, 0.0097886)
# cupyx.scipy.sparse.csc_matrix cuda (0.0157702, 0.0244233, 0.01783166)
# cupyx.scipy.sparse.csc_matrix sparse.DOK (0.8139113, 0.9298711, 0.86450981)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csc_matrix (0.0100744, 0.0110491, 0.01065992)
# cupyx.scipy.sparse.csc_matrix sparse.COO (0.1346421, 0.1610088, 0.1532939)
# cupyx.scipy.sparse.csc_matrix cupy (0.0443984, 0.0700217, 0.04758708)
# cupyx.scipy.sparse.csc_matrix numpy (0.0085154, 0.015385, 0.00978129)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.0032337, 0.0034744, 0.0033697)
# sparse.GCXS scipy.sparse.csr_matrix (0.3611069, 0.4060398, 0.37600336)
# sparse.GCXS numpy.matrix (0.055533, 0.0593346, 0.05694959)
# sparse.GCXS scipy.sparse.coo_matrix (0.3508971, 0.4119016, 0.38016824)
# sparse.GCXS cupyx.scipy.sparse.coo_matrix (0.4594684, 0.5059548, 0.47960541)
# sparse.GCXS cupyx.scipy.sparse.csc_matrix (0.4421648, 0.506064, 0.47599027)
# sparse.GCXS sparse.GCXS (1.4e-06, 2.69e-05, 1.615e-05)
# sparse.GCXS cuda (0.0474715, 0.0582099, 0.05275748)
# sparse.GCXS sparse.DOK (0.7672106, 0.8989059, 0.85363852)
# sparse.GCXS scipy.sparse.csc_matrix (0.374679, 0.4102647, 0.39251911)
# sparse.GCXS sparse.COO (0.0336417, 0.0482142, 0.03932804)
# sparse.GCXS cupy (0.0514547, 0.0620596, 0.05639892)
# sparse.GCXS numpy (0.0476126, 0.0561653, 0.04964975)
# sparse.GCXS cupyx.scipy.sparse.csr_matrix (0.4401927, 0.5015568, 0.4698627)
# cuda scipy.sparse.csr_matrix (0.0659741, 0.0757997, 0.06849603)
# cuda numpy.matrix (0.0055045, 0.0115814, 0.00715849)
# cuda scipy.sparse.coo_matrix (0.0622964, 0.0749036, 0.06719043)
# cuda cupyx.scipy.sparse.coo_matrix (0.0194868, 0.0867324, 0.02642474)
# cuda cupyx.scipy.sparse.csc_matrix (0.0480162, 0.058788, 0.05032621)
# cuda sparse.GCXS (0.0817778, 0.1122097, 0.08859502)
# cuda cuda (1.5e-06, 2.43e-05, 1.339e-05)
# cuda sparse.DOK (0.4073892, 0.4623638, 0.44135139)
# cuda scipy.sparse.csc_matrix (0.0716074, 0.0920069, 0.07839255)
# cuda sparse.COO (0.0500305, 0.0670923, 0.05350484)
# cuda cupy (0.0026143, 0.0027773, 0.00270518)
# cuda numpy (1.4e-06, 2.09e-05, 1.306e-05)
# cuda cupyx.scipy.sparse.csr_matrix (0.0477816, 0.0593446, 0.04938413)
# sparse.DOK scipy.sparse.csr_matrix (0.4020247, 0.4568238, 0.42894893)
# sparse.DOK numpy.matrix (0.1092272, 0.1437777, 0.12251845)
# sparse.DOK scipy.sparse.coo_matrix (0.4009747, 0.4709162, 0.42916841)
# sparse.DOK cupyx.scipy.sparse.coo_matrix (0.4170163, 0.4735188, 0.44956792)
# sparse.DOK cupyx.scipy.sparse.csc_matrix (0.4149655, 0.4702555, 0.43956515)
# sparse.DOK sparse.GCXS (0.4045632, 0.4922644, 0.43635561)
# sparse.DOK cuda (0.1017802, 0.1758869, 0.12824518)
# sparse.DOK sparse.DOK (1.4e-06, 2.41e-05, 1.616e-05)
# sparse.DOK scipy.sparse.csc_matrix (0.4211065, 0.490202, 0.46030054)
# sparse.DOK sparse.COO (0.3895592, 0.4606632, 0.4250845)
# sparse.DOK cupy (0.1124822, 0.1400191, 0.12498838)
# sparse.DOK numpy (0.1059806, 0.135208, 0.11823033)
# sparse.DOK cupyx.scipy.sparse.csr_matrix (0.4371673, 0.5069065, 0.45987103)
# scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.0050746, 0.0061792, 0.0054996)
# scipy.sparse.csc_matrix numpy.matrix (0.0684946, 0.0810134, 0.07307879)
# scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.0084789, 0.0152824, 0.01060489)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.0263355, 0.0299414, 0.02735876)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (0.0026426, 0.0045883, 0.00292798)
# scipy.sparse.csc_matrix sparse.GCXS (2.48e-05, 0.0001629, 0.00010905)
# scipy.sparse.csc_matrix cuda (0.0051062, 0.0059528, 0.00538367)
# scipy.sparse.csc_matrix sparse.DOK (0.8121939, 0.9812627, 0.91296357)
# scipy.sparse.csc_matrix scipy.sparse.csc_matrix (4.3e-06, 2.52e-05, 1.296e-05)
# scipy.sparse.csc_matrix sparse.COO (0.1026012, 0.1361331, 0.11731304)
# scipy.sparse.csc_matrix cupy (0.0482751, 0.0762932, 0.05177709)
# scipy.sparse.csc_matrix numpy (0.0051476, 0.0062577, 0.00545825)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.0076434, 0.0134381, 0.00863952)
# sparse.COO scipy.sparse.csr_matrix (0.0204375, 0.0213916, 0.02078962)
# sparse.COO numpy.matrix (0.0202199, 0.0302112, 0.02362814)
# sparse.COO scipy.sparse.coo_matrix (0.0188504, 0.0270659, 0.02096254)
# sparse.COO cupyx.scipy.sparse.coo_matrix (0.0342154, 0.0516011, 0.0420385)
# sparse.COO cupyx.scipy.sparse.csc_matrix (0.0349482, 0.0476932, 0.03903864)
# sparse.COO sparse.GCXS (0.0309694, 0.0420714, 0.03501943)
# sparse.COO cuda (0.0133174, 0.022927, 0.01465496)
# sparse.COO sparse.DOK (0.7679571, 0.9044709, 0.84704376)
# sparse.COO scipy.sparse.csc_matrix (0.029492, 0.0407531, 0.03454946)
# sparse.COO sparse.COO (1.9e-06, 2.45e-05, 1.571e-05)
# sparse.COO cupy (0.0175108, 0.0286829, 0.02025341)
# sparse.COO numpy (0.0132271, 0.0214125, 0.01620725)
# sparse.COO cupyx.scipy.sparse.csr_matrix (0.0283611, 0.0397368, 0.03059877)
# cupy scipy.sparse.csr_matrix (0.1089771, 0.1369451, 0.12303358)
# cupy numpy.matrix (0.0478864, 0.0542681, 0.05054565)
# cupy scipy.sparse.coo_matrix (0.1052872, 0.1341969, 0.11904488)
# cupy cupyx.scipy.sparse.coo_matrix (0.0314858, 0.0810758, 0.04152052)
# cupy cupyx.scipy.sparse.csc_matrix (0.0352255, 0.048262, 0.03795195)
# cupy sparse.GCXS (0.0956688, 0.122553, 0.10820665)
# cupy cuda (0.0108569, 0.0216237, 0.01813538)
# cupy sparse.DOK (0.4650128, 0.546801, 0.50905772)
# cupy scipy.sparse.csc_matrix (0.1148874, 0.1552267, 0.13346666)
# cupy sparse.COO (0.0929362, 0.1082539, 0.09894143)
# cupy cupy (1.2e-06, 3.48e-05, 1.734e-05)
# cupy numpy (0.0409458, 0.0419007, 0.04129853)
# cupy cupyx.scipy.sparse.csr_matrix (0.034149, 0.0483486, 0.0361525)
# numpy scipy.sparse.csr_matrix (0.0672778, 0.0952781, 0.07865694)
# numpy numpy.matrix (0.0055453, 0.0070505, 0.00669508)
# numpy scipy.sparse.coo_matrix (0.0658432, 0.0831719, 0.0726669)
# numpy cupyx.scipy.sparse.coo_matrix (0.0200118, 0.0580252, 0.05301622)
# numpy cupyx.scipy.sparse.csc_matrix (0.0502629, 0.0675709, 0.05427296)
# numpy sparse.GCXS (0.0826621, 0.1117918, 0.10012981)
# numpy cuda (1.5e-06, 2.39e-05, 1.651e-05)
# numpy sparse.DOK (0.4245968, 0.5312324, 0.47538513)
# numpy scipy.sparse.csc_matrix (0.0716993, 0.106303, 0.08593782)
# numpy sparse.COO (0.0513328, 0.0665339, 0.05733851)
# numpy cupy (0.0026642, 0.0044782, 0.00309234)
# numpy numpy (1.3e-06, 2.52e-05, 1.403e-05)
# numpy cupyx.scipy.sparse.csr_matrix (0.0473465, 0.0602345, 0.05010841)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csr_matrix (0.0025013, 0.0061479, 0.00352851)
# cupyx.scipy.sparse.csr_matrix numpy.matrix (0.0148208, 0.0218789, 0.01715979)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.0092677, 0.0162279, 0.01212154)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.0036579, 0.0046662, 0.00400256)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.0039152, 0.0132281, 0.01130015)
# cupyx.scipy.sparse.csr_matrix sparse.GCXS (0.0051751, 0.0112156, 0.00834753)
# cupyx.scipy.sparse.csr_matrix cuda (0.0139902, 0.0206718, 0.01613052)
# cupyx.scipy.sparse.csr_matrix sparse.DOK (0.7697485, 0.8549189, 0.81718251)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.0510408, 0.0542949, 0.05202263)
# cupyx.scipy.sparse.csr_matrix sparse.COO (0.0460263, 0.0623303, 0.04919191)
# cupyx.scipy.sparse.csr_matrix cupy (0.0413729, 0.0701708, 0.04461966)
# cupyx.scipy.sparse.csr_matrix numpy (0.0078454, 0.009864, 0.00841893)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (4.1e-06, 3.05e-05, 1.677e-05)

# %%
names = {
    spc.NUMPY: 'NUMPY',
    spc.NUMPY_MATRIX: 'NUMPY_MATRIX',
    spc.CUDA: 'CUDA',
    spc.CUPY: 'CUPY',
    spc.SPARSE_COO: 'SPARSE_COO',
    spc.SPARSE_GCXS: 'SPARSE_GCXS',
    spc.SPARSE_DOK: 'SPARSE_DOK',
    spc.SCIPY_COO: 'SCIPY_COO',
    spc.SCIPY_CSR: 'SCIPY_CSR',
    spc.SCIPY_CSC: 'SCIPY_CSC',
    spc.CUPY_SCIPY_COO: 'CUPY_SCIPY_COO',
    spc.CUPY_SCIPY_CSR: 'CUPY_SCIPY_CSR',
    spc.CUPY_SCIPY_CSC: 'CUPY_SCIPY_CSC',
}

# %%
for left in spc.BACKENDS:
    for right in spc.BACKENDS:
        print(f"    ({names[left]}, {names[right]}): {b[(left, right)][2]},")
# Out:
#     (SCIPY_CSR, SCIPY_CSR): 1.559e-05,
#     (SCIPY_CSR, NUMPY_MATRIX): 0.01296974,
#     (SCIPY_CSR, SCIPY_COO): 0.00750969,
#     (SCIPY_CSR, CUPY_SCIPY_COO): 0.01204903,
#     (SCIPY_CSR, CUPY_SCIPY_CSC): 0.01167255,
#     (SCIPY_CSR, SPARSE_GCXS): 0.00011317,
#     (SCIPY_CSR, CUDA): 0.00557031,
#     (SCIPY_CSR, SPARSE_DOK): 0.76682186,
#     (SCIPY_CSR, SCIPY_CSC): 0.01089365,
#     (SCIPY_CSR, SPARSE_COO): 0.01680042,
#     (SCIPY_CSR, CUPY): 0.04632367,
#     (SCIPY_CSR, NUMPY): 0.00495233,
#     (SCIPY_CSR, CUPY_SCIPY_CSR): 0.00258754,
#     (NUMPY_MATRIX, SCIPY_CSR): 0.07890904,
#     (NUMPY_MATRIX, NUMPY_MATRIX): 1.088e-05,
#     (NUMPY_MATRIX, SCIPY_COO): 0.07567136,
#     (NUMPY_MATRIX, CUPY_SCIPY_COO): 0.06118977,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSC): 0.06415718,
#     (NUMPY_MATRIX, SPARSE_GCXS): 0.08824788,
#     (NUMPY_MATRIX, CUDA): 0.00578329,
#     (NUMPY_MATRIX, SPARSE_DOK): 0.40563613,
#     (NUMPY_MATRIX, SCIPY_CSC): 0.08555071,
#     (NUMPY_MATRIX, SPARSE_COO): 0.0559763,
#     (NUMPY_MATRIX, CUPY): 0.01035024,
#     (NUMPY_MATRIX, NUMPY): 0.00535645,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSR): 0.05678837,
#     (SCIPY_COO, SCIPY_CSR): 0.00395482,
#     (SCIPY_COO, NUMPY_MATRIX): 0.0140713,
#     (SCIPY_COO, SCIPY_COO): 1.347e-05,
#     (SCIPY_COO, CUPY_SCIPY_COO): 0.00961638,
#     (SCIPY_COO, CUPY_SCIPY_CSC): 0.01900467,
#     (SCIPY_COO, SPARSE_GCXS): 0.00433509,
#     (SCIPY_COO, CUDA): 0.00515917,
#     (SCIPY_COO, SPARSE_DOK): 0.73489066,
#     (SCIPY_COO, SCIPY_CSC): 0.0104346,
#     (SCIPY_COO, SPARSE_COO): 0.00170327,
#     (SCIPY_COO, CUPY): 0.09446578,
#     (SCIPY_COO, NUMPY): 0.00495998,
#     (SCIPY_COO, CUPY_SCIPY_CSR): 0.00931616,
#     (CUPY_SCIPY_COO, SCIPY_CSR): 0.04777264,
#     (CUPY_SCIPY_COO, NUMPY_MATRIX): 0.02061129,
#     (CUPY_SCIPY_COO, SCIPY_COO): 0.00705612,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_COO): 1.379e-05,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSC): 0.05469087,
#     (CUPY_SCIPY_COO, SPARSE_GCXS): 0.0513449,
#     (CUPY_SCIPY_COO, CUDA): 0.01209151,
#     (CUPY_SCIPY_COO, SPARSE_DOK): 0.77208511,
#     (CUPY_SCIPY_COO, SCIPY_CSC): 0.0499516,
#     (CUPY_SCIPY_COO, SPARSE_COO): 0.02214925,
#     (CUPY_SCIPY_COO, CUPY): 0.09027534,
#     (CUPY_SCIPY_COO, NUMPY): 0.01201211,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSR): 0.03314292,
#     (CUPY_SCIPY_CSC, SCIPY_CSR): 0.00688394,
#     (CUPY_SCIPY_CSC, NUMPY_MATRIX): 0.07303444,
#     (CUPY_SCIPY_CSC, SCIPY_COO): 0.01199444,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_COO): 0.00533084,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSC): 1.648e-05,
#     (CUPY_SCIPY_CSC, SPARSE_GCXS): 0.0097886,
#     (CUPY_SCIPY_CSC, CUDA): 0.01783166,
#     (CUPY_SCIPY_CSC, SPARSE_DOK): 0.86450981,
#     (CUPY_SCIPY_CSC, SCIPY_CSC): 0.01065992,
#     (CUPY_SCIPY_CSC, SPARSE_COO): 0.1532939,
#     (CUPY_SCIPY_CSC, CUPY): 0.04758708,
#     (CUPY_SCIPY_CSC, NUMPY): 0.00978129,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSR): 0.0033697,
#     (SPARSE_GCXS, SCIPY_CSR): 0.37600336,
#     (SPARSE_GCXS, NUMPY_MATRIX): 0.05694959,
#     (SPARSE_GCXS, SCIPY_COO): 0.38016824,
#     (SPARSE_GCXS, CUPY_SCIPY_COO): 0.47960541,
#     (SPARSE_GCXS, CUPY_SCIPY_CSC): 0.47599027,
#     (SPARSE_GCXS, SPARSE_GCXS): 1.615e-05,
#     (SPARSE_GCXS, CUDA): 0.05275748,
#     (SPARSE_GCXS, SPARSE_DOK): 0.85363852,
#     (SPARSE_GCXS, SCIPY_CSC): 0.39251911,
#     (SPARSE_GCXS, SPARSE_COO): 0.03932804,
#     (SPARSE_GCXS, CUPY): 0.05639892,
#     (SPARSE_GCXS, NUMPY): 0.04964975,
#     (SPARSE_GCXS, CUPY_SCIPY_CSR): 0.4698627,
#     (CUDA, SCIPY_CSR): 0.06849603,
#     (CUDA, NUMPY_MATRIX): 0.00715849,
#     (CUDA, SCIPY_COO): 0.06719043,
#     (CUDA, CUPY_SCIPY_COO): 0.02642474,
#     (CUDA, CUPY_SCIPY_CSC): 0.05032621,
#     (CUDA, SPARSE_GCXS): 0.08859502,
#     (CUDA, CUDA): 1.339e-05,
#     (CUDA, SPARSE_DOK): 0.44135139,
#     (CUDA, SCIPY_CSC): 0.07839255,
#     (CUDA, SPARSE_COO): 0.05350484,
#     (CUDA, CUPY): 0.00270518,
#     (CUDA, NUMPY): 1.306e-05,
#     (CUDA, CUPY_SCIPY_CSR): 0.04938413,
#     (SPARSE_DOK, SCIPY_CSR): 0.42894893,
#     (SPARSE_DOK, NUMPY_MATRIX): 0.12251845,
#     (SPARSE_DOK, SCIPY_COO): 0.42916841,
#     (SPARSE_DOK, CUPY_SCIPY_COO): 0.44956792,
#     (SPARSE_DOK, CUPY_SCIPY_CSC): 0.43956515,
#     (SPARSE_DOK, SPARSE_GCXS): 0.43635561,
#     (SPARSE_DOK, CUDA): 0.12824518,
#     (SPARSE_DOK, SPARSE_DOK): 1.616e-05,
#     (SPARSE_DOK, SCIPY_CSC): 0.46030054,
#     (SPARSE_DOK, SPARSE_COO): 0.4250845,
#     (SPARSE_DOK, CUPY): 0.12498838,
#     (SPARSE_DOK, NUMPY): 0.11823033,
#     (SPARSE_DOK, CUPY_SCIPY_CSR): 0.45987103,
#     (SCIPY_CSC, SCIPY_CSR): 0.0054996,
#     (SCIPY_CSC, NUMPY_MATRIX): 0.07307879,
#     (SCIPY_CSC, SCIPY_COO): 0.01060489,
#     (SCIPY_CSC, CUPY_SCIPY_COO): 0.02735876,
#     (SCIPY_CSC, CUPY_SCIPY_CSC): 0.00292798,
#     (SCIPY_CSC, SPARSE_GCXS): 0.00010905,
#     (SCIPY_CSC, CUDA): 0.00538367,
#     (SCIPY_CSC, SPARSE_DOK): 0.91296357,
#     (SCIPY_CSC, SCIPY_CSC): 1.296e-05,
#     (SCIPY_CSC, SPARSE_COO): 0.11731304,
#     (SCIPY_CSC, CUPY): 0.05177709,
#     (SCIPY_CSC, NUMPY): 0.00545825,
#     (SCIPY_CSC, CUPY_SCIPY_CSR): 0.00863952,
#     (SPARSE_COO, SCIPY_CSR): 0.02078962,
#     (SPARSE_COO, NUMPY_MATRIX): 0.02362814,
#     (SPARSE_COO, SCIPY_COO): 0.02096254,
#     (SPARSE_COO, CUPY_SCIPY_COO): 0.0420385,
#     (SPARSE_COO, CUPY_SCIPY_CSC): 0.03903864,
#     (SPARSE_COO, SPARSE_GCXS): 0.03501943,
#     (SPARSE_COO, CUDA): 0.01465496,
#     (SPARSE_COO, SPARSE_DOK): 0.84704376,
#     (SPARSE_COO, SCIPY_CSC): 0.03454946,
#     (SPARSE_COO, SPARSE_COO): 1.571e-05,
#     (SPARSE_COO, CUPY): 0.02025341,
#     (SPARSE_COO, NUMPY): 0.01620725,
#     (SPARSE_COO, CUPY_SCIPY_CSR): 0.03059877,
#     (CUPY, SCIPY_CSR): 0.12303358,
#     (CUPY, NUMPY_MATRIX): 0.05054565,
#     (CUPY, SCIPY_COO): 0.11904488,
#     (CUPY, CUPY_SCIPY_COO): 0.04152052,
#     (CUPY, CUPY_SCIPY_CSC): 0.03795195,
#     (CUPY, SPARSE_GCXS): 0.10820665,
#     (CUPY, CUDA): 0.01813538,
#     (CUPY, SPARSE_DOK): 0.50905772,
#     (CUPY, SCIPY_CSC): 0.13346666,
#     (CUPY, SPARSE_COO): 0.09894143,
#     (CUPY, CUPY): 1.734e-05,
#     (CUPY, NUMPY): 0.04129853,
#     (CUPY, CUPY_SCIPY_CSR): 0.0361525,
#     (NUMPY, SCIPY_CSR): 0.07865694,
#     (NUMPY, NUMPY_MATRIX): 0.00669508,
#     (NUMPY, SCIPY_COO): 0.0726669,
#     (NUMPY, CUPY_SCIPY_COO): 0.05301622,
#     (NUMPY, CUPY_SCIPY_CSC): 0.05427296,
#     (NUMPY, SPARSE_GCXS): 0.10012981,
#     (NUMPY, CUDA): 1.651e-05,
#     (NUMPY, SPARSE_DOK): 0.47538513,
#     (NUMPY, SCIPY_CSC): 0.08593782,
#     (NUMPY, SPARSE_COO): 0.05733851,
#     (NUMPY, CUPY): 0.00309234,
#     (NUMPY, NUMPY): 1.403e-05,
#     (NUMPY, CUPY_SCIPY_CSR): 0.05010841,
#     (CUPY_SCIPY_CSR, SCIPY_CSR): 0.00352851,
#     (CUPY_SCIPY_CSR, NUMPY_MATRIX): 0.01715979,
#     (CUPY_SCIPY_CSR, SCIPY_COO): 0.01212154,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_COO): 0.00400256,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSC): 0.01130015,
#     (CUPY_SCIPY_CSR, SPARSE_GCXS): 0.00834753,
#     (CUPY_SCIPY_CSR, CUDA): 0.01613052,
#     (CUPY_SCIPY_CSR, SPARSE_DOK): 0.81718251,
#     (CUPY_SCIPY_CSR, SCIPY_CSC): 0.05202263,
#     (CUPY_SCIPY_CSR, SPARSE_COO): 0.04919191,
#     (CUPY_SCIPY_CSR, CUPY): 0.04461966,
#     (CUPY_SCIPY_CSR, NUMPY): 0.00841893,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSR): 1.677e-05,
