# %%
import numpy as np
import cupy

import sparseconverter as spc

# %%
b = spc.benchmark_conversions(
    shape=(32, 512, 512),
    dtype=np.float32,
    density=0.1,
    backends=spc.BACKENDS
)
# Out:
# scipy.sparse.csr_matrix scipy.sparse.csr_matrix (2.4e-06, 2.16e-05, 1.459e-05)
# scipy.sparse.csr_matrix cuda (0.0046672, 0.0052038, 0.00493635)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.0226185, 0.0245429, 0.02334584)
# scipy.sparse.csr_matrix sparse.COO (0.0163978, 0.0186223, 0.01763324)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (0.0022146, 0.0032909, 0.00245257)
# scipy.sparse.csr_matrix sparse.DOK (0.7711732, 1.0399743, 0.83002728)
# scipy.sparse.csr_matrix numpy (0.0047894, 0.0063414, 0.00552472)
# scipy.sparse.csr_matrix numpy.matrix (0.0048432, 0.0078155, 0.00569328)
# scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.0031452, 0.0047538, 0.00398569)
# scipy.sparse.csr_matrix cupy (0.0087952, 0.0159846, 0.01012645)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.011891, 0.0150006, 0.01313419)
# scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.0089537, 0.0102879, 0.00942009)
# scipy.sparse.csr_matrix sparse.GCXS (0.0016395, 0.0030301, 0.00215682)
# cuda scipy.sparse.csr_matrix (0.0682545, 0.080275, 0.07387733)
# cuda cuda (1e-06, 2.05e-05, 1.397e-05)
# cuda cupyx.scipy.sparse.coo_matrix (0.0193516, 0.1253017, 0.03676262)
# cuda sparse.COO (0.0511879, 0.0673112, 0.06164377)
# cuda cupyx.scipy.sparse.csr_matrix (0.0197294, 0.1236165, 0.03029807)
# cuda sparse.DOK (0.3838579, 0.4480199, 0.41626783)
# cuda numpy (2.2e-06, 1.54e-05, 1.101e-05)
# cuda numpy.matrix (1.77e-05, 0.0002205, 0.00014465)
# cuda scipy.sparse.coo_matrix (0.0659194, 0.0788133, 0.07126909)
# cuda cupy (0.0024899, 0.0035357, 0.00290094)
# cuda cupyx.scipy.sparse.csc_matrix (0.0186817, 0.0456342, 0.02478382)
# cuda scipy.sparse.csc_matrix (0.0742106, 0.0820521, 0.07710105)
# cuda sparse.GCXS (0.0832534, 0.0956669, 0.08713908)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.044526, 0.0471014, 0.04540595)
# cupyx.scipy.sparse.coo_matrix cuda (0.0119944, 0.0138895, 0.01279124)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (1.4e-06, 1.43e-05, 9.8e-06)
# cupyx.scipy.sparse.coo_matrix sparse.COO (0.0204995, 0.0261808, 0.02240446)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.0284474, 0.0727495, 0.03350027)
# cupyx.scipy.sparse.coo_matrix sparse.DOK (0.7626438, 0.8934977, 0.81763242)
# cupyx.scipy.sparse.coo_matrix numpy (0.0187178, 0.0209477, 0.01959753)
# cupyx.scipy.sparse.coo_matrix numpy.matrix (0.0187471, 0.0205572, 0.01955723)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.coo_matrix (0.0134152, 0.0142153, 0.0140366)
# cupyx.scipy.sparse.coo_matrix cupy (0.0808699, 0.090932, 0.08431704)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.0285436, 0.0424613, 0.03095062)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.0462124, 0.0688723, 0.05566742)
# cupyx.scipy.sparse.coo_matrix sparse.GCXS (0.0483039, 0.0623535, 0.0503551)
# sparse.COO scipy.sparse.csr_matrix (0.0222329, 0.0319062, 0.02506089)
# sparse.COO cuda (0.0094323, 0.022396, 0.01227037)
# sparse.COO cupyx.scipy.sparse.coo_matrix (0.0293674, 0.0360584, 0.03187509)
# sparse.COO sparse.COO (9e-07, 1.79e-05, 1.328e-05)
# sparse.COO cupyx.scipy.sparse.csr_matrix (0.0263096, 0.0327843, 0.02893439)
# sparse.COO sparse.DOK (0.8138606, 0.8677859, 0.83920339)
# sparse.COO numpy (0.0087551, 0.0136318, 0.0098226)
# sparse.COO numpy.matrix (0.0088459, 0.0135347, 0.01040078)
# sparse.COO scipy.sparse.coo_matrix (0.0193649, 0.0229677, 0.02069974)
# sparse.COO cupy (0.0119854, 0.0179492, 0.01397232)
# sparse.COO cupyx.scipy.sparse.csc_matrix (0.036085, 0.0447285, 0.03986542)
# sparse.COO scipy.sparse.csc_matrix (0.0284517, 0.0371115, 0.03106024)
# sparse.COO sparse.GCXS (0.031997, 0.052748, 0.03594461)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csr_matrix (0.0085715, 0.0095236, 0.00912916)
# cupyx.scipy.sparse.csr_matrix cuda (0.0136383, 0.0151802, 0.01429861)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.0126883, 0.0167112, 0.01443459)
# cupyx.scipy.sparse.csr_matrix sparse.COO (0.0267055, 0.0336705, 0.02864303)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (1.1e-06, 1.71e-05, 1.167e-05)
# cupyx.scipy.sparse.csr_matrix sparse.DOK (0.7690206, 0.8614229, 0.80137306)
# cupyx.scipy.sparse.csr_matrix numpy (0.0137742, 0.0185416, 0.01489683)
# cupyx.scipy.sparse.csr_matrix numpy.matrix (0.0138402, 0.0160986, 0.01469383)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.0122149, 0.0143577, 0.01336538)
# cupyx.scipy.sparse.csr_matrix cupy (0.039129, 0.0638252, 0.04460615)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.0019084, 0.0029247, 0.002124)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.0128437, 0.0150666, 0.0139769)
# cupyx.scipy.sparse.csr_matrix sparse.GCXS (0.0069053, 0.0087614, 0.00764849)
# sparse.DOK scipy.sparse.csr_matrix (0.3965454, 0.4744333, 0.42915226)
# sparse.DOK cuda (0.1014066, 0.1298695, 0.11058626)
# sparse.DOK cupyx.scipy.sparse.coo_matrix (0.4250663, 0.4660354, 0.44371138)
# sparse.DOK sparse.COO (0.3786314, 0.4548443, 0.41190378)
# sparse.DOK cupyx.scipy.sparse.csr_matrix (0.4000037, 0.4765442, 0.43226047)
# sparse.DOK sparse.DOK (9e-07, 1.69e-05, 1.187e-05)
# sparse.DOK numpy (0.1014772, 0.1289157, 0.11354399)
# sparse.DOK numpy.matrix (0.1005118, 0.1239626, 0.10729896)
# sparse.DOK scipy.sparse.coo_matrix (0.3921629, 0.4585311, 0.42308864)
# sparse.DOK cupy (0.1031431, 0.1214668, 0.10950506)
# sparse.DOK cupyx.scipy.sparse.csc_matrix (0.4034745, 0.4566323, 0.4265934)
# sparse.DOK scipy.sparse.csc_matrix (0.4004078, 0.5076596, 0.45172044)
# sparse.DOK sparse.GCXS (0.4058318, 0.465586, 0.4325561)
# numpy scipy.sparse.csr_matrix (0.0690043, 0.0835232, 0.07519809)
# numpy cuda (1e-06, 1.68e-05, 1.228e-05)
# numpy cupyx.scipy.sparse.coo_matrix (0.019112, 0.1308389, 0.03072501)
# numpy sparse.COO (0.0535081, 0.0714055, 0.06172041)
# numpy cupyx.scipy.sparse.csr_matrix (0.0208147, 0.0655043, 0.02565548)
# numpy sparse.DOK (0.3827169, 0.4542014, 0.41673362)
# numpy numpy (1.19e-05, 8.09e-05, 2.177e-05)
# numpy numpy.matrix (1.7e-05, 0.0001877, 0.00011643)
# numpy scipy.sparse.coo_matrix (0.0650562, 0.0803815, 0.071367)
# numpy cupy (0.0025916, 0.0030943, 0.00275125)
# numpy cupyx.scipy.sparse.csc_matrix (0.0214079, 0.0960228, 0.03698203)
# numpy scipy.sparse.csc_matrix (0.0738184, 0.1118941, 0.08173664)
# numpy sparse.GCXS (0.0825648, 0.0970621, 0.08833201)
# numpy.matrix scipy.sparse.csr_matrix (0.0700162, 0.081995, 0.07470251)
# numpy.matrix cuda (1.4e-06, 2.94e-05, 1.812e-05)
# numpy.matrix cupyx.scipy.sparse.coo_matrix (0.0192523, 0.0900181, 0.02692905)
# numpy.matrix sparse.COO (0.0446923, 0.0703853, 0.05499004)
# numpy.matrix cupyx.scipy.sparse.csr_matrix (0.0220864, 0.0652624, 0.02930477)
# numpy.matrix sparse.DOK (0.3324315, 0.419148, 0.36448452)
# numpy.matrix numpy (1.48e-05, 0.0001163, 3.088e-05)
# numpy.matrix numpy.matrix (1.1e-06, 1.93e-05, 1.357e-05)
# numpy.matrix scipy.sparse.coo_matrix (0.0655164, 0.0854279, 0.07221178)
# numpy.matrix cupy (0.0025663, 0.0030746, 0.00284773)
# numpy.matrix cupyx.scipy.sparse.csc_matrix (0.0186269, 0.0458319, 0.0248778)
# numpy.matrix scipy.sparse.csc_matrix (0.0748793, 0.0929529, 0.08215391)
# numpy.matrix sparse.GCXS (0.0745059, 0.0888282, 0.07961737)
# scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.0037046, 0.0050671, 0.00409992)
# scipy.sparse.coo_matrix cuda (0.0046684, 0.0070169, 0.00554266)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (0.0206095, 0.0213714, 0.02096826)
# scipy.sparse.coo_matrix sparse.COO (0.0012481, 0.002049, 0.0015528)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.0070954, 0.0110518, 0.00833004)
# scipy.sparse.coo_matrix sparse.DOK (0.7247559, 0.7984668, 0.76291548)
# scipy.sparse.coo_matrix numpy (0.0049123, 0.0066757, 0.0057289)
# scipy.sparse.coo_matrix numpy.matrix (0.0047572, 0.0056635, 0.00514385)
# scipy.sparse.coo_matrix scipy.sparse.coo_matrix (1.3e-06, 3.27e-05, 1.483e-05)
# scipy.sparse.coo_matrix cupy (0.0085855, 0.0127087, 0.01049599)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.0144053, 0.0240295, 0.01695301)
# scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.0078947, 0.0106059, 0.00908695)
# scipy.sparse.coo_matrix sparse.GCXS (0.0037626, 0.0048948, 0.00415204)
# cupy scipy.sparse.csr_matrix (0.1114459, 0.1245207, 0.11560138)
# cupy cuda (0.0410699, 0.0419534, 0.04128729)
# cupy cupyx.scipy.sparse.coo_matrix (0.0092538, 0.0817303, 0.03479637)
# cupy sparse.COO (0.072539, 0.0931318, 0.08293617)
# cupy cupyx.scipy.sparse.csr_matrix (0.0086761, 0.0827993, 0.02077345)
# cupy sparse.DOK (0.3803589, 0.5295961, 0.45851607)
# cupy numpy (0.0410911, 0.0419163, 0.04131443)
# cupy numpy.matrix (0.0411489, 0.0417425, 0.04139519)
# cupy scipy.sparse.coo_matrix (0.1088802, 0.120016, 0.11484382)
# cupy cupy (9e-07, 1.8e-05, 1.315e-05)
# cupy cupyx.scipy.sparse.csc_matrix (0.0221475, 0.0514238, 0.02891527)
# cupy scipy.sparse.csc_matrix (0.1173364, 0.1294165, 0.12240084)
# cupy sparse.GCXS (0.1260638, 0.1503593, 0.13566548)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.0228782, 0.0525236, 0.04601307)
# cupyx.scipy.sparse.csc_matrix cuda (0.0111766, 0.0129238, 0.01170401)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.0146605, 0.0180241, 0.0154935)
# cupyx.scipy.sparse.csc_matrix sparse.COO (0.0894148, 0.1002305, 0.09272055)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.0054262, 0.0418346, 0.01317206)
# cupyx.scipy.sparse.csc_matrix sparse.DOK (0.7912646, 1.0536489, 0.87353325)
# cupyx.scipy.sparse.csc_matrix numpy (0.0155133, 0.0173839, 0.01652527)
# cupyx.scipy.sparse.csc_matrix numpy.matrix (0.0156782, 0.0177363, 0.01623056)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.0298148, 0.0331571, 0.03094247)
# cupyx.scipy.sparse.csc_matrix cupy (0.0430827, 0.066626, 0.04833271)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (1.6e-06, 1.55e-05, 1.079e-05)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csc_matrix (0.0031861, 0.0042601, 0.00378959)
# cupyx.scipy.sparse.csc_matrix sparse.GCXS (0.0096179, 0.0133219, 0.01177203)
# scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.0044538, 0.0066342, 0.00556892)
# scipy.sparse.csc_matrix cuda (0.0049973, 0.0057731, 0.00534249)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.0247947, 0.0269387, 0.02545826)
# scipy.sparse.csc_matrix sparse.COO (0.0670906, 0.0807884, 0.07105924)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.0073647, 0.011275, 0.00827505)
# scipy.sparse.csc_matrix sparse.DOK (0.7965524, 0.8516839, 0.82178102)
# scipy.sparse.csc_matrix numpy (0.0049455, 0.0082024, 0.00567323)
# scipy.sparse.csc_matrix numpy.matrix (0.0049919, 0.0063324, 0.00572489)
# scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.0047445, 0.0071042, 0.00559732)
# scipy.sparse.csc_matrix cupy (0.0090951, 0.0141059, 0.01051322)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (0.0025587, 0.0033458, 0.00291492)
# scipy.sparse.csc_matrix scipy.sparse.csc_matrix (1e-06, 1.83e-05, 1.329e-05)
# scipy.sparse.csc_matrix sparse.GCXS (0.0030955, 0.0053557, 0.00404301)
# sparse.GCXS scipy.sparse.csr_matrix (0.3108927, 0.3475495, 0.32723106)
# sparse.GCXS cuda (0.0451565, 0.061068, 0.05120677)
# sparse.GCXS cupyx.scipy.sparse.coo_matrix (0.4463831, 0.4948476, 0.47022746)
# sparse.GCXS sparse.COO (0.0364963, 0.0474859, 0.03921757)
# sparse.GCXS cupyx.scipy.sparse.csr_matrix (0.4169692, 0.4777217, 0.44203396)
# sparse.GCXS sparse.DOK (0.8008456, 0.9452849, 0.87211339)
# sparse.GCXS numpy (0.0450443, 0.0614531, 0.04957471)
# sparse.GCXS numpy.matrix (0.0457203, 0.0562513, 0.04963172)
# sparse.GCXS scipy.sparse.coo_matrix (0.322564, 0.4330881, 0.36567051)
# sparse.GCXS cupy (0.0493745, 0.0649259, 0.05303882)
# sparse.GCXS cupyx.scipy.sparse.csc_matrix (0.426816, 0.5095042, 0.45507096)
# sparse.GCXS scipy.sparse.csc_matrix (0.3324416, 0.3600987, 0.34491236)
# sparse.GCXS sparse.GCXS (1e-06, 1.7e-05, 1.298e-05)

# %%
names = {
    spc.NUMPY: 'NUMPY',
    spc.NUMPY_MATRIX: 'NUMPY_MATRIX',
    spc.CUDA: 'CUDA',
    spc.CUPY: 'CUPY',
    spc.SPARSE_COO: 'SPARSE_COO',
    spc.SPARSE_GCXS: 'SPARSE_GCXS',
    spc.SPARSE_DOK: 'SPARSE_DOK',
    spc.SCIPY_COO: 'SCIPY_COO',
    spc.SCIPY_CSR: 'SCIPY_CSR',
    spc.SCIPY_CSC: 'SCIPY_CSC',
    spc.CUPY_SCIPY_COO: 'CUPY_SCIPY_COO',
    spc.CUPY_SCIPY_CSR: 'CUPY_SCIPY_CSR',
    spc.CUPY_SCIPY_CSC: 'CUPY_SCIPY_CSC',
}

# %%
for left in sorted(spc.BACKENDS):
    for right in sorted(spc.BACKENDS):
        print(f"    ({names[left]}, {names[right]}): {b[(left, right)][2]},")
# Out:
#     (CUDA, CUDA): 1.397e-05,
#     (CUDA, CUPY): 0.00290094,
#     (CUDA, CUPY_SCIPY_COO): 0.03676262,
#     (CUDA, CUPY_SCIPY_CSC): 0.02478382,
#     (CUDA, CUPY_SCIPY_CSR): 0.03029807,
#     (CUDA, NUMPY): 1.101e-05,
#     (CUDA, NUMPY_MATRIX): 0.00014465,
#     (CUDA, SCIPY_COO): 0.07126909,
#     (CUDA, SCIPY_CSC): 0.07710105,
#     (CUDA, SCIPY_CSR): 0.07387733,
#     (CUDA, SPARSE_COO): 0.06164377,
#     (CUDA, SPARSE_DOK): 0.41626783,
#     (CUDA, SPARSE_GCXS): 0.08713908,
#     (CUPY, CUDA): 0.04128729,
#     (CUPY, CUPY): 1.315e-05,
#     (CUPY, CUPY_SCIPY_COO): 0.03479637,
#     (CUPY, CUPY_SCIPY_CSC): 0.02891527,
#     (CUPY, CUPY_SCIPY_CSR): 0.02077345,
#     (CUPY, NUMPY): 0.04131443,
#     (CUPY, NUMPY_MATRIX): 0.04139519,
#     (CUPY, SCIPY_COO): 0.11484382,
#     (CUPY, SCIPY_CSC): 0.12240084,
#     (CUPY, SCIPY_CSR): 0.11560138,
#     (CUPY, SPARSE_COO): 0.08293617,
#     (CUPY, SPARSE_DOK): 0.45851607,
#     (CUPY, SPARSE_GCXS): 0.13566548,
#     (CUPY_SCIPY_COO, CUDA): 0.01279124,
#     (CUPY_SCIPY_COO, CUPY): 0.08431704,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_COO): 9.8e-06,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSC): 0.03095062,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSR): 0.03350027,
#     (CUPY_SCIPY_COO, NUMPY): 0.01959753,
#     (CUPY_SCIPY_COO, NUMPY_MATRIX): 0.01955723,
#     (CUPY_SCIPY_COO, SCIPY_COO): 0.0140366,
#     (CUPY_SCIPY_COO, SCIPY_CSC): 0.05566742,
#     (CUPY_SCIPY_COO, SCIPY_CSR): 0.04540595,
#     (CUPY_SCIPY_COO, SPARSE_COO): 0.02240446,
#     (CUPY_SCIPY_COO, SPARSE_DOK): 0.81763242,
#     (CUPY_SCIPY_COO, SPARSE_GCXS): 0.0503551,
#     (CUPY_SCIPY_CSC, CUDA): 0.01170401,
#     (CUPY_SCIPY_CSC, CUPY): 0.04833271,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_COO): 0.0154935,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSC): 1.079e-05,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSR): 0.01317206,
#     (CUPY_SCIPY_CSC, NUMPY): 0.01652527,
#     (CUPY_SCIPY_CSC, NUMPY_MATRIX): 0.01623056,
#     (CUPY_SCIPY_CSC, SCIPY_COO): 0.03094247,
#     (CUPY_SCIPY_CSC, SCIPY_CSC): 0.00378959,
#     (CUPY_SCIPY_CSC, SCIPY_CSR): 0.04601307,
#     (CUPY_SCIPY_CSC, SPARSE_COO): 0.09272055,
#     (CUPY_SCIPY_CSC, SPARSE_DOK): 0.87353325,
#     (CUPY_SCIPY_CSC, SPARSE_GCXS): 0.01177203,
#     (CUPY_SCIPY_CSR, CUDA): 0.01429861,
#     (CUPY_SCIPY_CSR, CUPY): 0.04460615,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_COO): 0.01443459,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSC): 0.002124,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSR): 1.167e-05,
#     (CUPY_SCIPY_CSR, NUMPY): 0.01489683,
#     (CUPY_SCIPY_CSR, NUMPY_MATRIX): 0.01469383,
#     (CUPY_SCIPY_CSR, SCIPY_COO): 0.01336538,
#     (CUPY_SCIPY_CSR, SCIPY_CSC): 0.0139769,
#     (CUPY_SCIPY_CSR, SCIPY_CSR): 0.00912916,
#     (CUPY_SCIPY_CSR, SPARSE_COO): 0.02864303,
#     (CUPY_SCIPY_CSR, SPARSE_DOK): 0.80137306,
#     (CUPY_SCIPY_CSR, SPARSE_GCXS): 0.00764849,
#     (NUMPY, CUDA): 1.228e-05,
#     (NUMPY, CUPY): 0.00275125,
#     (NUMPY, CUPY_SCIPY_COO): 0.03072501,
#     (NUMPY, CUPY_SCIPY_CSC): 0.03698203,
#     (NUMPY, CUPY_SCIPY_CSR): 0.02565548,
#     (NUMPY, NUMPY): 2.177e-05,
#     (NUMPY, NUMPY_MATRIX): 0.00011643,
#     (NUMPY, SCIPY_COO): 0.071367,
#     (NUMPY, SCIPY_CSC): 0.08173664,
#     (NUMPY, SCIPY_CSR): 0.07519809,
#     (NUMPY, SPARSE_COO): 0.06172041,
#     (NUMPY, SPARSE_DOK): 0.41673362,
#     (NUMPY, SPARSE_GCXS): 0.08833201,
#     (NUMPY_MATRIX, CUDA): 1.812e-05,
#     (NUMPY_MATRIX, CUPY): 0.00284773,
#     (NUMPY_MATRIX, CUPY_SCIPY_COO): 0.02692905,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSC): 0.0248778,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSR): 0.02930477,
#     (NUMPY_MATRIX, NUMPY): 3.088e-05,
#     (NUMPY_MATRIX, NUMPY_MATRIX): 1.357e-05,
#     (NUMPY_MATRIX, SCIPY_COO): 0.07221178,
#     (NUMPY_MATRIX, SCIPY_CSC): 0.08215391,
#     (NUMPY_MATRIX, SCIPY_CSR): 0.07470251,
#     (NUMPY_MATRIX, SPARSE_COO): 0.05499004,
#     (NUMPY_MATRIX, SPARSE_DOK): 0.36448452,
#     (NUMPY_MATRIX, SPARSE_GCXS): 0.07961737,
#     (SCIPY_COO, CUDA): 0.00554266,
#     (SCIPY_COO, CUPY): 0.01049599,
#     (SCIPY_COO, CUPY_SCIPY_COO): 0.02096826,
#     (SCIPY_COO, CUPY_SCIPY_CSC): 0.01695301,
#     (SCIPY_COO, CUPY_SCIPY_CSR): 0.00833004,
#     (SCIPY_COO, NUMPY): 0.0057289,
#     (SCIPY_COO, NUMPY_MATRIX): 0.00514385,
#     (SCIPY_COO, SCIPY_COO): 1.483e-05,
#     (SCIPY_COO, SCIPY_CSC): 0.00908695,
#     (SCIPY_COO, SCIPY_CSR): 0.00409992,
#     (SCIPY_COO, SPARSE_COO): 0.0015528,
#     (SCIPY_COO, SPARSE_DOK): 0.76291548,
#     (SCIPY_COO, SPARSE_GCXS): 0.00415204,
#     (SCIPY_CSC, CUDA): 0.00534249,
#     (SCIPY_CSC, CUPY): 0.01051322,
#     (SCIPY_CSC, CUPY_SCIPY_COO): 0.02545826,
#     (SCIPY_CSC, CUPY_SCIPY_CSC): 0.00291492,
#     (SCIPY_CSC, CUPY_SCIPY_CSR): 0.00827505,
#     (SCIPY_CSC, NUMPY): 0.00567323,
#     (SCIPY_CSC, NUMPY_MATRIX): 0.00572489,
#     (SCIPY_CSC, SCIPY_COO): 0.00559732,
#     (SCIPY_CSC, SCIPY_CSC): 1.329e-05,
#     (SCIPY_CSC, SCIPY_CSR): 0.00556892,
#     (SCIPY_CSC, SPARSE_COO): 0.07105924,
#     (SCIPY_CSC, SPARSE_DOK): 0.82178102,
#     (SCIPY_CSC, SPARSE_GCXS): 0.00404301,
#     (SCIPY_CSR, CUDA): 0.00493635,
#     (SCIPY_CSR, CUPY): 0.01012645,
#     (SCIPY_CSR, CUPY_SCIPY_COO): 0.02334584,
#     (SCIPY_CSR, CUPY_SCIPY_CSC): 0.01313419,
#     (SCIPY_CSR, CUPY_SCIPY_CSR): 0.00245257,
#     (SCIPY_CSR, NUMPY): 0.00552472,
#     (SCIPY_CSR, NUMPY_MATRIX): 0.00569328,
#     (SCIPY_CSR, SCIPY_COO): 0.00398569,
#     (SCIPY_CSR, SCIPY_CSC): 0.00942009,
#     (SCIPY_CSR, SCIPY_CSR): 1.459e-05,
#     (SCIPY_CSR, SPARSE_COO): 0.01763324,
#     (SCIPY_CSR, SPARSE_DOK): 0.83002728,
#     (SCIPY_CSR, SPARSE_GCXS): 0.00215682,
#     (SPARSE_COO, CUDA): 0.01227037,
#     (SPARSE_COO, CUPY): 0.01397232,
#     (SPARSE_COO, CUPY_SCIPY_COO): 0.03187509,
#     (SPARSE_COO, CUPY_SCIPY_CSC): 0.03986542,
#     (SPARSE_COO, CUPY_SCIPY_CSR): 0.02893439,
#     (SPARSE_COO, NUMPY): 0.0098226,
#     (SPARSE_COO, NUMPY_MATRIX): 0.01040078,
#     (SPARSE_COO, SCIPY_COO): 0.02069974,
#     (SPARSE_COO, SCIPY_CSC): 0.03106024,
#     (SPARSE_COO, SCIPY_CSR): 0.02506089,
#     (SPARSE_COO, SPARSE_COO): 1.328e-05,
#     (SPARSE_COO, SPARSE_DOK): 0.83920339,
#     (SPARSE_COO, SPARSE_GCXS): 0.03594461,
#     (SPARSE_DOK, CUDA): 0.11058626,
#     (SPARSE_DOK, CUPY): 0.10950506,
#     (SPARSE_DOK, CUPY_SCIPY_COO): 0.44371138,
#     (SPARSE_DOK, CUPY_SCIPY_CSC): 0.4265934,
#     (SPARSE_DOK, CUPY_SCIPY_CSR): 0.43226047,
#     (SPARSE_DOK, NUMPY): 0.11354399,
#     (SPARSE_DOK, NUMPY_MATRIX): 0.10729896,
#     (SPARSE_DOK, SCIPY_COO): 0.42308864,
#     (SPARSE_DOK, SCIPY_CSC): 0.45172044,
#     (SPARSE_DOK, SCIPY_CSR): 0.42915226,
#     (SPARSE_DOK, SPARSE_COO): 0.41190378,
#     (SPARSE_DOK, SPARSE_DOK): 1.187e-05,
#     (SPARSE_DOK, SPARSE_GCXS): 0.4325561,
#     (SPARSE_GCXS, CUDA): 0.05120677,
#     (SPARSE_GCXS, CUPY): 0.05303882,
#     (SPARSE_GCXS, CUPY_SCIPY_COO): 0.47022746,
#     (SPARSE_GCXS, CUPY_SCIPY_CSC): 0.45507096,
#     (SPARSE_GCXS, CUPY_SCIPY_CSR): 0.44203396,
#     (SPARSE_GCXS, NUMPY): 0.04957471,
#     (SPARSE_GCXS, NUMPY_MATRIX): 0.04963172,
#     (SPARSE_GCXS, SCIPY_COO): 0.36567051,
#     (SPARSE_GCXS, SCIPY_CSC): 0.34491236,
#     (SPARSE_GCXS, SCIPY_CSR): 0.32723106,
#     (SPARSE_GCXS, SPARSE_COO): 0.03921757,
#     (SPARSE_GCXS, SPARSE_DOK): 0.87211339,
#     (SPARSE_GCXS, SPARSE_GCXS): 1.298e-05,
