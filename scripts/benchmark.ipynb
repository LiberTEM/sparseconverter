# %%
import numpy as np
import cupy

import sparseconverter as spc

# %%
b = spc.benchmark_conversions(
    shape=(32, 512, 512),
    dtype=np.float32,
    density=0.1,
    backends=spc.BACKENDS
)
# Out:
# cupy cupy (2.1e-06, 2.55e-05, 1.746e-05)
# cupy cupyx.scipy.sparse.coo_matrix (0.0057518, 0.0068297, 0.00611991)
# cupy scipy.sparse.coo_matrix (0.0737582, 0.1005364, 0.08598811)
# cupy cupyx.scipy.sparse.csc_matrix (0.0354843, 0.0487722, 0.03733477)
# cupy numpy.matrix (0.0106916, 0.0142884, 0.01126993)
# cupy sparse.COO (0.0628261, 0.0831929, 0.06873951)
# cupy cupyx.scipy.sparse.csr_matrix (0.0344364, 0.0480505, 0.03686613)
# cupy scipy.sparse.csc_matrix (0.0827519, 0.120722, 0.09904028)
# cupy numpy (0.010541, 0.0214188, 0.01721894)
# cupy cuda (0.0208067, 0.0213097, 0.02103729)
# cupy scipy.sparse.csr_matrix (0.0905948, 0.1334357, 0.11549778)
# cupy sparse.DOK (0.5052469, 0.7391605, 0.60264757)
# cupy sparse.GCXS (0.1259695, 0.1524148, 0.13803982)
# cupyx.scipy.sparse.coo_matrix cupy (0.084155, 0.0954091, 0.08669025)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (1.6e-06, 3.46e-05, 2.035e-05)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.coo_matrix (0.0069866, 0.0142459, 0.00878497)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.0312325, 0.0504929, 0.03449509)
# cupyx.scipy.sparse.coo_matrix numpy.matrix (0.0125435, 0.0184988, 0.01469767)
# cupyx.scipy.sparse.coo_matrix sparse.COO (0.020579, 0.033968, 0.026937)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.0325881, 0.0751154, 0.03776613)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.0482912, 0.053862, 0.0504526)
# cupyx.scipy.sparse.coo_matrix numpy (0.012343, 0.021912, 0.01443599)
# cupyx.scipy.sparse.coo_matrix cuda (0.0119655, 0.0214823, 0.01566148)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.0490988, 0.0766113, 0.05749875)
# cupyx.scipy.sparse.coo_matrix sparse.DOK (0.8850873, 1.005626, 0.94401879)
# cupyx.scipy.sparse.coo_matrix sparse.GCXS (0.0487246, 0.052359, 0.05015882)
# scipy.sparse.coo_matrix cupy (0.0934853, 0.1201394, 0.09828147)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (0.0095582, 0.0170657, 0.01147509)
# scipy.sparse.coo_matrix scipy.sparse.coo_matrix (1.4e-06, 2.7e-05, 1.725e-05)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.0164508, 0.0274088, 0.02020869)
# scipy.sparse.coo_matrix numpy.matrix (0.0050556, 0.0088392, 0.00613688)
# scipy.sparse.coo_matrix sparse.COO (0.0013082, 0.002641, 0.0019966)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.0096549, 0.0173645, 0.01365494)
# scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.0092167, 0.0206279, 0.01231984)
# scipy.sparse.coo_matrix numpy (0.0050362, 0.0077692, 0.00587683)
# scipy.sparse.coo_matrix cuda (0.005067, 0.0100773, 0.00669893)
# scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.0037538, 0.0057022, 0.00435175)
# scipy.sparse.coo_matrix sparse.DOK (0.8427348, 0.9944082, 0.90540777)
# scipy.sparse.coo_matrix sparse.GCXS (0.0038225, 0.0069821, 0.00480937)
# cupyx.scipy.sparse.csc_matrix cupy (0.0452741, 0.0715862, 0.04833837)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.0039132, 0.0059294, 0.00446527)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.0096854, 0.0149454, 0.01096469)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (1.4e-06, 2.12e-05, 1.294e-05)
# cupyx.scipy.sparse.csc_matrix numpy.matrix (0.0093563, 0.0133225, 0.01198516)
# cupyx.scipy.sparse.csc_matrix sparse.COO (0.1571371, 0.199795, 0.17522068)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.0122565, 0.0590625, 0.02633535)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csc_matrix (0.0063381, 0.0112677, 0.00844066)
# cupyx.scipy.sparse.csc_matrix numpy (0.0163192, 0.0193216, 0.01742636)
# cupyx.scipy.sparse.csc_matrix cuda (0.0160969, 0.0214084, 0.01781985)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.029439, 0.0769812, 0.06151143)
# cupyx.scipy.sparse.csc_matrix sparse.DOK (0.8701868, 1.5307869, 1.11465743)
# cupyx.scipy.sparse.csc_matrix sparse.GCXS (0.0105748, 0.0112623, 0.01081873)
# numpy.matrix cupy (0.0026665, 0.0094301, 0.00381775)
# numpy.matrix cupyx.scipy.sparse.coo_matrix (0.0192991, 0.0211855, 0.01968527)
# numpy.matrix scipy.sparse.coo_matrix (0.069198, 0.1098837, 0.09087968)
# numpy.matrix cupyx.scipy.sparse.csc_matrix (0.0487998, 0.0600316, 0.05140539)
# numpy.matrix numpy.matrix (1.6e-06, 3.28e-05, 2.045e-05)
# numpy.matrix sparse.COO (0.0520583, 0.0740559, 0.06258441)
# numpy.matrix cupyx.scipy.sparse.csr_matrix (0.0485079, 0.0963298, 0.05500352)
# numpy.matrix scipy.sparse.csc_matrix (0.0745523, 0.1163192, 0.09439166)
# numpy.matrix numpy (5.1e-06, 3.77e-05, 2.487e-05)
# numpy.matrix cuda (5.4e-06, 5.65e-05, 3.461e-05)
# numpy.matrix scipy.sparse.csr_matrix (0.0736969, 0.0957139, 0.08286627)
# numpy.matrix sparse.DOK (0.4794389, 0.5491988, 0.51177968)
# numpy.matrix sparse.GCXS (0.0805519, 0.1086451, 0.09821756)
# sparse.COO cupy (0.0191812, 0.0274184, 0.02297915)
# sparse.COO cupyx.scipy.sparse.coo_matrix (0.0303545, 0.045135, 0.03703372)
# sparse.COO scipy.sparse.coo_matrix (0.0200887, 0.0410673, 0.02701171)
# sparse.COO cupyx.scipy.sparse.csc_matrix (0.0368061, 0.0718294, 0.04454681)
# sparse.COO numpy.matrix (0.0132285, 0.0167466, 0.01444951)
# sparse.COO sparse.COO (1.5e-06, 2.51e-05, 1.717e-05)
# sparse.COO cupyx.scipy.sparse.csr_matrix (0.0277685, 0.0455548, 0.03332745)
# sparse.COO scipy.sparse.csc_matrix (0.0292421, 0.0481703, 0.03586587)
# sparse.COO numpy (0.0134944, 0.0192956, 0.01488837)
# sparse.COO cuda (0.0134217, 0.0173253, 0.01489712)
# sparse.COO scipy.sparse.csr_matrix (0.0215691, 0.0370383, 0.02805333)
# sparse.COO sparse.DOK (0.8318255, 1.0623734, 0.94475679)
# sparse.COO sparse.GCXS (0.0320397, 0.0582222, 0.04260282)
# cupyx.scipy.sparse.csr_matrix cupy (0.0421959, 0.0703241, 0.04592677)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.0034345, 0.0054809, 0.00392839)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.0103512, 0.0138853, 0.01168824)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.0026716, 0.0041185, 0.00361826)
# cupyx.scipy.sparse.csr_matrix numpy.matrix (0.0094902, 0.0157244, 0.01278352)
# cupyx.scipy.sparse.csr_matrix sparse.COO (0.0370138, 0.0488531, 0.04230864)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (1.5e-06, 2.41e-05, 1.667e-05)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.0503767, 0.0527019, 0.0515299)
# cupyx.scipy.sparse.csr_matrix numpy (0.0155783, 0.0198324, 0.01688748)
# cupyx.scipy.sparse.csr_matrix cuda (0.0144861, 0.0183767, 0.01601441)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csr_matrix (0.0086048, 0.0105072, 0.00936075)
# cupyx.scipy.sparse.csr_matrix sparse.DOK (0.7315479, 0.8666252, 0.80736131)
# cupyx.scipy.sparse.csr_matrix sparse.GCXS (0.0088765, 0.0106352, 0.0093434)
# scipy.sparse.csc_matrix cupy (0.0487187, 0.0730793, 0.05190711)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.0129035, 0.0178565, 0.01436357)
# scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.0085432, 0.0111449, 0.00926209)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (0.0026476, 0.0079271, 0.00381339)
# scipy.sparse.csc_matrix numpy.matrix (0.00514, 0.0104704, 0.00613965)
# scipy.sparse.csc_matrix sparse.COO (0.1078815, 0.1653607, 0.13768478)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.0091169, 0.018806, 0.0120841)
# scipy.sparse.csc_matrix scipy.sparse.csc_matrix (1.9e-06, 2.77e-05, 1.538e-05)
# scipy.sparse.csc_matrix numpy (0.0052929, 0.0108117, 0.00663408)
# scipy.sparse.csc_matrix cuda (0.0056083, 0.0111408, 0.00758184)
# scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.0049179, 0.0123865, 0.0072822)
# scipy.sparse.csc_matrix sparse.DOK (0.9719603, 1.1599137, 1.07214478)
# scipy.sparse.csc_matrix sparse.GCXS (6.84e-05, 0.0001823, 0.00013719)
# numpy cupy (0.0026575, 0.0045472, 0.00354766)
# numpy cupyx.scipy.sparse.coo_matrix (0.0211125, 0.0227074, 0.0215568)
# numpy scipy.sparse.coo_matrix (0.0678456, 0.095621, 0.08312593)
# numpy cupyx.scipy.sparse.csc_matrix (0.0487119, 0.0588251, 0.05158394)
# numpy numpy.matrix (1.54e-05, 0.0001743, 0.0001257)
# numpy sparse.COO (0.0503277, 0.0828753, 0.05567686)
# numpy cupyx.scipy.sparse.csr_matrix (0.0483, 0.0912904, 0.05538303)
# numpy scipy.sparse.csc_matrix (0.0777096, 0.103999, 0.08787844)
# numpy numpy (1.4e-06, 2.42e-05, 1.501e-05)
# numpy cuda (1.2e-06, 2.77e-05, 1.387e-05)
# numpy scipy.sparse.csr_matrix (0.0656555, 0.0889237, 0.07730333)
# numpy sparse.DOK (0.441912, 0.6153584, 0.52556944)
# numpy sparse.GCXS (0.0893924, 0.1411052, 0.11135973)
# cuda cupy (0.0027877, 0.0051944, 0.00327691)
# cuda cupyx.scipy.sparse.coo_matrix (0.0204203, 0.0243865, 0.02172871)
# cuda scipy.sparse.coo_matrix (0.0707062, 0.087591, 0.0798874)
# cuda cupyx.scipy.sparse.csc_matrix (0.0489759, 0.060619, 0.0514298)
# cuda numpy.matrix (1.71e-05, 0.0001826, 9.663e-05)
# cuda sparse.COO (0.0498664, 0.0604354, 0.05332664)
# cuda cupyx.scipy.sparse.csr_matrix (0.0478691, 0.090491, 0.05322665)
# cuda scipy.sparse.csc_matrix (0.072006, 0.0944878, 0.08399213)
# cuda numpy (1.5e-06, 2.28e-05, 1.472e-05)
# cuda cuda (2.7e-06, 2.4e-05, 1.78e-05)
# cuda scipy.sparse.csr_matrix (0.0667635, 0.0842564, 0.07586088)
# cuda sparse.DOK (0.4480011, 0.5604665, 0.49659468)
# cuda sparse.GCXS (0.0903664, 0.1183702, 0.10562099)
# scipy.sparse.csr_matrix cupy (0.0454938, 0.0733775, 0.05062383)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.0116212, 0.0198908, 0.01503088)
# scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.0079397, 0.0181264, 0.00954869)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.0129182, 0.0234199, 0.01652452)
# scipy.sparse.csr_matrix numpy.matrix (0.0048842, 0.0088132, 0.00597422)
# scipy.sparse.csr_matrix sparse.COO (0.0167525, 0.0376203, 0.02558507)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (0.0025324, 0.0048503, 0.00330172)
# scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.0099581, 0.0155392, 0.012819)
# scipy.sparse.csr_matrix numpy (0.0050686, 0.0095576, 0.00725681)
# scipy.sparse.csr_matrix cuda (0.0049515, 0.0085988, 0.00606321)
# scipy.sparse.csr_matrix scipy.sparse.csr_matrix (2.4e-06, 3.02e-05, 1.585e-05)
# scipy.sparse.csr_matrix sparse.DOK (0.7660671, 0.8828618, 0.82405482)
# scipy.sparse.csr_matrix sparse.GCXS (2.26e-05, 0.0001632, 0.00012854)
# sparse.DOK cupy (0.109251, 0.1366276, 0.12289178)
# sparse.DOK cupyx.scipy.sparse.coo_matrix (0.4340372, 0.49948, 0.46856752)
# sparse.DOK scipy.sparse.coo_matrix (0.415631, 0.4713966, 0.44466105)
# sparse.DOK cupyx.scipy.sparse.csc_matrix (0.4120663, 0.5123259, 0.46209415)
# sparse.DOK numpy.matrix (0.10149, 0.1388937, 0.12442799)
# sparse.DOK sparse.COO (0.3827938, 0.455636, 0.42131579)
# sparse.DOK cupyx.scipy.sparse.csr_matrix (0.4654949, 0.6247092, 0.53057096)
# sparse.DOK scipy.sparse.csc_matrix (0.458304, 0.6195074, 0.54459229)
# sparse.DOK numpy (0.1199066, 0.158235, 0.13981908)
# sparse.DOK cuda (0.1119179, 0.1861062, 0.14330484)
# sparse.DOK scipy.sparse.csr_matrix (0.497462, 0.6083453, 0.54751204)
# sparse.DOK sparse.DOK (2.2e-06, 4.14e-05, 2.062e-05)
# sparse.DOK sparse.GCXS (0.4911541, 0.5737018, 0.52582061)
# sparse.GCXS cupy (0.0610319, 0.0858648, 0.07099481)
# sparse.GCXS cupyx.scipy.sparse.coo_matrix (0.5263303, 0.6625244, 0.59167055)
# sparse.GCXS scipy.sparse.coo_matrix (0.4169423, 0.5146283, 0.4430832)
# sparse.GCXS cupyx.scipy.sparse.csc_matrix (0.4687617, 0.5430438, 0.51215087)
# sparse.GCXS numpy.matrix (0.0472237, 0.0669214, 0.05313108)
# sparse.GCXS sparse.COO (0.0332357, 0.0399433, 0.0354407)
# sparse.GCXS cupyx.scipy.sparse.csr_matrix (0.4501583, 0.5207944, 0.4812603)
# sparse.GCXS scipy.sparse.csc_matrix (0.3609227, 0.4773629, 0.42519233)
# sparse.GCXS numpy (0.0467784, 0.0676208, 0.05019734)
# sparse.GCXS cuda (0.0469524, 0.0572908, 0.04990786)
# sparse.GCXS scipy.sparse.csr_matrix (0.3759274, 0.4498989, 0.40662121)
# sparse.GCXS sparse.DOK (0.8650116, 1.1080163, 0.92272439)
# sparse.GCXS sparse.GCXS (2.1e-06, 2.7e-05, 1.63e-05)

# %%
names = {
    spc.NUMPY: 'NUMPY',
    spc.NUMPY_MATRIX: 'NUMPY_MATRIX',
    spc.CUDA: 'CUDA',
    spc.CUPY: 'CUPY',
    spc.SPARSE_COO: 'SPARSE_COO',
    spc.SPARSE_GCXS: 'SPARSE_GCXS',
    spc.SPARSE_DOK: 'SPARSE_DOK',
    spc.SCIPY_COO: 'SCIPY_COO',
    spc.SCIPY_CSR: 'SCIPY_CSR',
    spc.SCIPY_CSC: 'SCIPY_CSC',
    spc.CUPY_SCIPY_COO: 'CUPY_SCIPY_COO',
    spc.CUPY_SCIPY_CSR: 'CUPY_SCIPY_CSR',
    spc.CUPY_SCIPY_CSC: 'CUPY_SCIPY_CSC',
}

# %%
for left in spc.BACKENDS:
    for right in spc.BACKENDS:
        print(f"    ({names[left]}, {names[right]}): {b[(left, right)][2]},")
# Out:
#     (CUPY, CUPY): 1.746e-05,
#     (CUPY, CUPY_SCIPY_COO): 0.00611991,
#     (CUPY, SCIPY_COO): 0.08598811,
#     (CUPY, CUPY_SCIPY_CSC): 0.03733477,
#     (CUPY, NUMPY_MATRIX): 0.01126993,
#     (CUPY, SPARSE_COO): 0.06873951,
#     (CUPY, CUPY_SCIPY_CSR): 0.03686613,
#     (CUPY, SCIPY_CSC): 0.09904028,
#     (CUPY, NUMPY): 0.01721894,
#     (CUPY, CUDA): 0.02103729,
#     (CUPY, SCIPY_CSR): 0.11549778,
#     (CUPY, SPARSE_DOK): 0.60264757,
#     (CUPY, SPARSE_GCXS): 0.13803982,
#     (CUPY_SCIPY_COO, CUPY): 0.08669025,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_COO): 2.035e-05,
#     (CUPY_SCIPY_COO, SCIPY_COO): 0.00878497,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSC): 0.03449509,
#     (CUPY_SCIPY_COO, NUMPY_MATRIX): 0.01469767,
#     (CUPY_SCIPY_COO, SPARSE_COO): 0.026937,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSR): 0.03776613,
#     (CUPY_SCIPY_COO, SCIPY_CSC): 0.0504526,
#     (CUPY_SCIPY_COO, NUMPY): 0.01443599,
#     (CUPY_SCIPY_COO, CUDA): 0.01566148,
#     (CUPY_SCIPY_COO, SCIPY_CSR): 0.05749875,
#     (CUPY_SCIPY_COO, SPARSE_DOK): 0.94401879,
#     (CUPY_SCIPY_COO, SPARSE_GCXS): 0.05015882,
#     (SCIPY_COO, CUPY): 0.09828147,
#     (SCIPY_COO, CUPY_SCIPY_COO): 0.01147509,
#     (SCIPY_COO, SCIPY_COO): 1.725e-05,
#     (SCIPY_COO, CUPY_SCIPY_CSC): 0.02020869,
#     (SCIPY_COO, NUMPY_MATRIX): 0.00613688,
#     (SCIPY_COO, SPARSE_COO): 0.0019966,
#     (SCIPY_COO, CUPY_SCIPY_CSR): 0.01365494,
#     (SCIPY_COO, SCIPY_CSC): 0.01231984,
#     (SCIPY_COO, NUMPY): 0.00587683,
#     (SCIPY_COO, CUDA): 0.00669893,
#     (SCIPY_COO, SCIPY_CSR): 0.00435175,
#     (SCIPY_COO, SPARSE_DOK): 0.90540777,
#     (SCIPY_COO, SPARSE_GCXS): 0.00480937,
#     (CUPY_SCIPY_CSC, CUPY): 0.04833837,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_COO): 0.00446527,
#     (CUPY_SCIPY_CSC, SCIPY_COO): 0.01096469,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSC): 1.294e-05,
#     (CUPY_SCIPY_CSC, NUMPY_MATRIX): 0.01198516,
#     (CUPY_SCIPY_CSC, SPARSE_COO): 0.17522068,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSR): 0.02633535,
#     (CUPY_SCIPY_CSC, SCIPY_CSC): 0.00844066,
#     (CUPY_SCIPY_CSC, NUMPY): 0.01742636,
#     (CUPY_SCIPY_CSC, CUDA): 0.01781985,
#     (CUPY_SCIPY_CSC, SCIPY_CSR): 0.06151143,
#     (CUPY_SCIPY_CSC, SPARSE_DOK): 1.11465743,
#     (CUPY_SCIPY_CSC, SPARSE_GCXS): 0.01081873,
#     (NUMPY_MATRIX, CUPY): 0.00381775,
#     (NUMPY_MATRIX, CUPY_SCIPY_COO): 0.01968527,
#     (NUMPY_MATRIX, SCIPY_COO): 0.09087968,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSC): 0.05140539,
#     (NUMPY_MATRIX, NUMPY_MATRIX): 2.045e-05,
#     (NUMPY_MATRIX, SPARSE_COO): 0.06258441,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSR): 0.05500352,
#     (NUMPY_MATRIX, SCIPY_CSC): 0.09439166,
#     (NUMPY_MATRIX, NUMPY): 2.487e-05,
#     (NUMPY_MATRIX, CUDA): 3.461e-05,
#     (NUMPY_MATRIX, SCIPY_CSR): 0.08286627,
#     (NUMPY_MATRIX, SPARSE_DOK): 0.51177968,
#     (NUMPY_MATRIX, SPARSE_GCXS): 0.09821756,
#     (SPARSE_COO, CUPY): 0.02297915,
#     (SPARSE_COO, CUPY_SCIPY_COO): 0.03703372,
#     (SPARSE_COO, SCIPY_COO): 0.02701171,
#     (SPARSE_COO, CUPY_SCIPY_CSC): 0.04454681,
#     (SPARSE_COO, NUMPY_MATRIX): 0.01444951,
#     (SPARSE_COO, SPARSE_COO): 1.717e-05,
#     (SPARSE_COO, CUPY_SCIPY_CSR): 0.03332745,
#     (SPARSE_COO, SCIPY_CSC): 0.03586587,
#     (SPARSE_COO, NUMPY): 0.01488837,
#     (SPARSE_COO, CUDA): 0.01489712,
#     (SPARSE_COO, SCIPY_CSR): 0.02805333,
#     (SPARSE_COO, SPARSE_DOK): 0.94475679,
#     (SPARSE_COO, SPARSE_GCXS): 0.04260282,
#     (CUPY_SCIPY_CSR, CUPY): 0.04592677,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_COO): 0.00392839,
#     (CUPY_SCIPY_CSR, SCIPY_COO): 0.01168824,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSC): 0.00361826,
#     (CUPY_SCIPY_CSR, NUMPY_MATRIX): 0.01278352,
#     (CUPY_SCIPY_CSR, SPARSE_COO): 0.04230864,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSR): 1.667e-05,
#     (CUPY_SCIPY_CSR, SCIPY_CSC): 0.0515299,
#     (CUPY_SCIPY_CSR, NUMPY): 0.01688748,
#     (CUPY_SCIPY_CSR, CUDA): 0.01601441,
#     (CUPY_SCIPY_CSR, SCIPY_CSR): 0.00936075,
#     (CUPY_SCIPY_CSR, SPARSE_DOK): 0.80736131,
#     (CUPY_SCIPY_CSR, SPARSE_GCXS): 0.0093434,
#     (SCIPY_CSC, CUPY): 0.05190711,
#     (SCIPY_CSC, CUPY_SCIPY_COO): 0.01436357,
#     (SCIPY_CSC, SCIPY_COO): 0.00926209,
#     (SCIPY_CSC, CUPY_SCIPY_CSC): 0.00381339,
#     (SCIPY_CSC, NUMPY_MATRIX): 0.00613965,
#     (SCIPY_CSC, SPARSE_COO): 0.13768478,
#     (SCIPY_CSC, CUPY_SCIPY_CSR): 0.0120841,
#     (SCIPY_CSC, SCIPY_CSC): 1.538e-05,
#     (SCIPY_CSC, NUMPY): 0.00663408,
#     (SCIPY_CSC, CUDA): 0.00758184,
#     (SCIPY_CSC, SCIPY_CSR): 0.0072822,
#     (SCIPY_CSC, SPARSE_DOK): 1.07214478,
#     (SCIPY_CSC, SPARSE_GCXS): 0.00013719,
#     (NUMPY, CUPY): 0.00354766,
#     (NUMPY, CUPY_SCIPY_COO): 0.0215568,
#     (NUMPY, SCIPY_COO): 0.08312593,
#     (NUMPY, CUPY_SCIPY_CSC): 0.05158394,
#     (NUMPY, NUMPY_MATRIX): 0.0001257,
#     (NUMPY, SPARSE_COO): 0.05567686,
#     (NUMPY, CUPY_SCIPY_CSR): 0.05538303,
#     (NUMPY, SCIPY_CSC): 0.08787844,
#     (NUMPY, NUMPY): 1.501e-05,
#     (NUMPY, CUDA): 1.387e-05,
#     (NUMPY, SCIPY_CSR): 0.07730333,
#     (NUMPY, SPARSE_DOK): 0.52556944,
#     (NUMPY, SPARSE_GCXS): 0.11135973,
#     (CUDA, CUPY): 0.00327691,
#     (CUDA, CUPY_SCIPY_COO): 0.02172871,
#     (CUDA, SCIPY_COO): 0.0798874,
#     (CUDA, CUPY_SCIPY_CSC): 0.0514298,
#     (CUDA, NUMPY_MATRIX): 9.663e-05,
#     (CUDA, SPARSE_COO): 0.05332664,
#     (CUDA, CUPY_SCIPY_CSR): 0.05322665,
#     (CUDA, SCIPY_CSC): 0.08399213,
#     (CUDA, NUMPY): 1.472e-05,
#     (CUDA, CUDA): 1.78e-05,
#     (CUDA, SCIPY_CSR): 0.07586088,
#     (CUDA, SPARSE_DOK): 0.49659468,
#     (CUDA, SPARSE_GCXS): 0.10562099,
#     (SCIPY_CSR, CUPY): 0.05062383,
#     (SCIPY_CSR, CUPY_SCIPY_COO): 0.01503088,
#     (SCIPY_CSR, SCIPY_COO): 0.00954869,
#     (SCIPY_CSR, CUPY_SCIPY_CSC): 0.01652452,
#     (SCIPY_CSR, NUMPY_MATRIX): 0.00597422,
#     (SCIPY_CSR, SPARSE_COO): 0.02558507,
#     (SCIPY_CSR, CUPY_SCIPY_CSR): 0.00330172,
#     (SCIPY_CSR, SCIPY_CSC): 0.012819,
#     (SCIPY_CSR, NUMPY): 0.00725681,
#     (SCIPY_CSR, CUDA): 0.00606321,
#     (SCIPY_CSR, SCIPY_CSR): 1.585e-05,
#     (SCIPY_CSR, SPARSE_DOK): 0.82405482,
#     (SCIPY_CSR, SPARSE_GCXS): 0.00012854,
#     (SPARSE_DOK, CUPY): 0.12289178,
#     (SPARSE_DOK, CUPY_SCIPY_COO): 0.46856752,
#     (SPARSE_DOK, SCIPY_COO): 0.44466105,
#     (SPARSE_DOK, CUPY_SCIPY_CSC): 0.46209415,
#     (SPARSE_DOK, NUMPY_MATRIX): 0.12442799,
#     (SPARSE_DOK, SPARSE_COO): 0.42131579,
#     (SPARSE_DOK, CUPY_SCIPY_CSR): 0.53057096,
#     (SPARSE_DOK, SCIPY_CSC): 0.54459229,
#     (SPARSE_DOK, NUMPY): 0.13981908,
#     (SPARSE_DOK, CUDA): 0.14330484,
#     (SPARSE_DOK, SCIPY_CSR): 0.54751204,
#     (SPARSE_DOK, SPARSE_DOK): 2.062e-05,
#     (SPARSE_DOK, SPARSE_GCXS): 0.52582061,
#     (SPARSE_GCXS, CUPY): 0.07099481,
#     (SPARSE_GCXS, CUPY_SCIPY_COO): 0.59167055,
#     (SPARSE_GCXS, SCIPY_COO): 0.4430832,
#     (SPARSE_GCXS, CUPY_SCIPY_CSC): 0.51215087,
#     (SPARSE_GCXS, NUMPY_MATRIX): 0.05313108,
#     (SPARSE_GCXS, SPARSE_COO): 0.0354407,
#     (SPARSE_GCXS, CUPY_SCIPY_CSR): 0.4812603,
#     (SPARSE_GCXS, SCIPY_CSC): 0.42519233,
#     (SPARSE_GCXS, NUMPY): 0.05019734,
#     (SPARSE_GCXS, CUDA): 0.04990786,
#     (SPARSE_GCXS, SCIPY_CSR): 0.40662121,
#     (SPARSE_GCXS, SPARSE_DOK): 0.92272439,
#     (SPARSE_GCXS, SPARSE_GCXS): 1.63e-05,
