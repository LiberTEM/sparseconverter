# %%
import numpy as np
import cupy

import sparseconverter as spc

# %%
b = spc.benchmark_conversions(
    shape=(32, 512, 512),
    dtype=np.float32,
    density=0.1,
    backends=spc.BACKENDS
)
# Out:
# cuda cuda (1.993e-06, 7.665e-06, 5.7087e-06)
# cuda scipy.sparse.coo_matrix (0.05379057, 0.056568509, 0.0542562901)
# cuda cupyx.scipy.sparse.csr_matrix (0.006767722, 0.00943542, 0.0072124011)
# cuda sparse.GCXS (0.085998586, 0.092506643, 0.0869229908)
# cuda numpy (1.333e-06, 6.252e-06, 5.3775e-06)
# cuda cupyx.scipy.sparse.csc_matrix (0.003757972, 0.004733786, 0.0044373838)
# cuda cupyx.scipy.sparse.coo_matrix (0.004677629, 0.004826833, 0.0047700987)
# cuda numpy.matrix (1.6041e-05, 6.86e-05, 6.19358e-05)
# cuda scipy.sparse.csc_matrix (0.057588908, 0.059388137, 0.0579072341)
# cuda cupy (0.00225774, 0.012817097, 0.0033369292000000003)
# cuda sparse.DOK (0.425054898, 0.471613515, 0.4593789143)
# cuda scipy.sparse.csr_matrix (0.058553171, 0.060548903, 0.0590351847)
# cuda sparse.COO (0.045593563, 0.051303174, 0.047494878399999996)
# scipy.sparse.coo_matrix cuda (0.004020199, 0.009851341, 0.0068673172000000005)
# scipy.sparse.coo_matrix scipy.sparse.coo_matrix (1.273e-06, 6.833e-06, 5.3601000000000006e-06)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.007412025, 0.007656781, 0.0075110757000000005)
# scipy.sparse.coo_matrix sparse.GCXS (0.004897848, 0.005149446, 0.0051015318)
# scipy.sparse.coo_matrix numpy (0.004022313, 0.01148177, 0.007202438)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.008271549, 0.008406325, 0.0083373677)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (0.002795562, 0.00295254, 0.0029265753)
# scipy.sparse.coo_matrix numpy.matrix (0.004130068, 0.010648376, 0.0071584635)
# scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.003474924, 0.004145488, 0.0038445701)
# scipy.sparse.coo_matrix cupy (0.006465767, 0.014754709, 0.0104031465)
# scipy.sparse.coo_matrix sparse.DOK (0.991563372, 1.058595909, 1.0414961782)
# scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.005025329, 0.005208207, 0.0051002343)
# scipy.sparse.coo_matrix sparse.COO (0.000379431, 0.000727192, 0.0005566118000000001)
# cupyx.scipy.sparse.csr_matrix cuda (0.010163514, 0.011481999, 0.0107578735)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.002361898, 0.002844275, 0.0025163781)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (1.142e-06, 6.413e-06, 5.4963e-06)
# cupyx.scipy.sparse.csr_matrix sparse.GCXS (0.001742521, 0.00214199, 0.0019567613)
# cupyx.scipy.sparse.csr_matrix numpy (0.010162101, 0.011664747, 0.010612198599999999)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.000304809, 0.000540918, 0.0005096146)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.000711482, 0.001080523, 0.0010201825999999999)
# cupyx.scipy.sparse.csr_matrix numpy.matrix (0.010280877, 0.011354758, 0.0106934284)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.004480494, 0.005047001, 0.0048487582999999996)
# cupyx.scipy.sparse.csr_matrix cupy (0.005905031, 0.0064564, 0.0061654453)
# cupyx.scipy.sparse.csr_matrix sparse.DOK (1.018292084, 1.082697548, 1.0502791334)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csr_matrix (0.000579752, 0.00078957, 0.0007281086999999999)
# cupyx.scipy.sparse.csr_matrix sparse.COO (0.010520322, 0.01197126, 0.010840902599999999)
# sparse.GCXS cuda (0.041328168, 0.042039581, 0.0415628543)
# sparse.GCXS scipy.sparse.coo_matrix (0.153364588, 0.15607092, 0.15432492269999998)
# sparse.GCXS cupyx.scipy.sparse.csr_matrix (0.244666815, 0.253143624, 0.250026516)
# sparse.GCXS sparse.GCXS (1.012e-06, 6.793e-06, 5.6678999999999996e-06)
# sparse.GCXS numpy (0.041049999, 0.042412329, 0.0417246977)
# sparse.GCXS cupyx.scipy.sparse.csc_matrix (0.252519468, 0.25816144, 0.2550338915)
# sparse.GCXS cupyx.scipy.sparse.coo_matrix (0.24946305, 0.25562511, 0.2519524705)
# sparse.GCXS numpy.matrix (0.040992511, 0.042914383, 0.0416986575)
# sparse.GCXS scipy.sparse.csc_matrix (0.157843069, 0.159408624, 0.15875735259999998)
# sparse.GCXS cupy (0.043751324, 0.044534532, 0.0440102195)
# sparse.GCXS sparse.DOK (1.143783365, 1.181620074, 1.1691816655)
# sparse.GCXS scipy.sparse.csr_matrix (0.153487312, 0.155473618, 0.1543013657)
# sparse.GCXS sparse.COO (0.027183369, 0.03222541, 0.028974817)
# numpy cuda (1.543e-06, 6.613e-06, 5.6909e-06)
# numpy scipy.sparse.coo_matrix (0.053598387, 0.054380533, 0.0538344536)
# numpy cupyx.scipy.sparse.csr_matrix (0.006743495, 0.009674345, 0.0071185418)
# numpy sparse.GCXS (0.086305422, 0.092688873, 0.08869084040000001)
# numpy numpy (1.163e-06, 6.662e-06, 5.3913e-06)
# numpy cupyx.scipy.sparse.csc_matrix (0.003710742, 0.004511703, 0.0043844903)
# numpy cupyx.scipy.sparse.coo_matrix (0.003976487, 0.004762972, 0.0046167395)
# numpy numpy.matrix (1.2253e-05, 6.9483e-05, 6.228640000000001e-05)
# numpy scipy.sparse.csc_matrix (0.057519038, 0.058365867, 0.057908801)
# numpy cupy (0.002039726, 0.002297747, 0.0022502914)
# numpy sparse.DOK (0.426000921, 0.469496167, 0.4619955832)
# numpy scipy.sparse.csr_matrix (0.058000202, 0.060069755, 0.0587481384)
# numpy sparse.COO (0.045519134, 0.050432241, 0.0475574139)
# cupyx.scipy.sparse.csc_matrix cuda (0.012510634, 0.01382332, 0.0133224155)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.002124868, 0.002490153, 0.0024322171)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.000293628, 0.000535548, 0.0004962211)
# cupyx.scipy.sparse.csc_matrix sparse.GCXS (0.005507886, 0.007125892, 0.0063828478)
# cupyx.scipy.sparse.csc_matrix numpy (0.012420945, 0.013711587, 0.0132182667)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (1.343e-06, 6.913e-06, 5.9003999999999994e-06)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.000713566, 0.001083049, 0.0010126644)
# cupyx.scipy.sparse.csc_matrix numpy.matrix (0.01245568, 0.013811607, 0.0132212654)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csc_matrix (0.000678359, 0.000865365, 0.0008341843000000001)
# cupyx.scipy.sparse.csc_matrix cupy (0.006094873, 0.006791387, 0.0061948457)
# cupyx.scipy.sparse.csc_matrix sparse.DOK (1.072331066, 1.126696881, 1.1066260407000001)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.000903587, 0.001202906, 0.0011534851000000001)
# cupyx.scipy.sparse.csc_matrix sparse.COO (0.055853122, 0.060449507, 0.057683317399999996)
# cupyx.scipy.sparse.coo_matrix cuda (0.012310174, 0.013017679, 0.0125646027)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.coo_matrix (0.001369844, 0.001560827, 0.001516897)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.004630279, 0.004928757, 0.0046695442)
# cupyx.scipy.sparse.coo_matrix sparse.GCXS (0.007000584, 0.007291036, 0.0072367965999999995)
# cupyx.scipy.sparse.coo_matrix numpy (0.012343538, 0.013450411, 0.012788232699999999)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.004629588, 0.004926643, 0.0046786442)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (1.683e-06, 6.613e-06, 5.8401e-06)
# cupyx.scipy.sparse.coo_matrix numpy.matrix (0.012356261, 0.013582532, 0.012631248199999999)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.005771778, 0.006222925, 0.0061664394)
# cupyx.scipy.sparse.coo_matrix cupy (0.010628769, 0.011430271, 0.0107726843)
# cupyx.scipy.sparse.coo_matrix sparse.DOK (1.007384139, 1.074318099, 1.0562659261)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.00566741, 0.006229738, 0.0060853895)
# cupyx.scipy.sparse.coo_matrix sparse.COO (0.00966145, 0.010500906, 0.0098726427)
# numpy.matrix cuda (1.653e-06, 1.058e-05, 9.0764e-06)
# numpy.matrix scipy.sparse.coo_matrix (0.053858623, 0.054697726, 0.054201784600000004)
# numpy.matrix cupyx.scipy.sparse.csr_matrix (0.006857903, 0.009056982, 0.007215551099999999)
# numpy.matrix sparse.GCXS (0.078796344, 0.085538065, 0.080696045)
# numpy.matrix numpy (1.302e-06, 9.418e-06, 7.9e-06)
# numpy.matrix cupyx.scipy.sparse.csc_matrix (0.003765005, 0.004656529, 0.0044369469000000005)
# numpy.matrix cupyx.scipy.sparse.coo_matrix (0.004043775, 0.004909069, 0.0046872365)
# numpy.matrix numpy.matrix (1.212e-06, 6.272e-06, 5.5805e-06)
# numpy.matrix scipy.sparse.csc_matrix (0.057708589, 0.059274254, 0.0582682783)
# numpy.matrix cupy (0.002093249, 0.002365305, 0.0023160705)
# numpy.matrix sparse.DOK (0.364118729, 0.408516803, 0.4020413502)
# numpy.matrix scipy.sparse.csr_matrix (0.058746732, 0.060240712, 0.0592015605)
# numpy.matrix sparse.COO (0.03965513, 0.044837749, 0.0405218495)
# scipy.sparse.csc_matrix cuda (0.004460246, 0.013168606, 0.0087067581)
# scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.00349916, 0.003854264, 0.0036872113)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.006762842, 0.00698765, 0.0068246185)
# scipy.sparse.csc_matrix sparse.GCXS (0.002650266, 0.003114829, 0.0029355244)
# scipy.sparse.csc_matrix numpy (0.004459525, 0.013186469, 0.0085353636)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (0.00143645, 0.001777087, 0.0017166193999999999)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.005823447, 0.006041942, 0.005907114)
# scipy.sparse.csc_matrix numpy.matrix (0.004548885, 0.013351593, 0.008607367599999999)
# scipy.sparse.csc_matrix scipy.sparse.csc_matrix (1.173e-06, 1.9437e-05, 6.9375e-06)
# scipy.sparse.csc_matrix cupy (0.006897167, 0.018109836, 0.0122098977)
# scipy.sparse.csc_matrix sparse.DOK (1.056165715, 1.105142102, 1.0925487128)
# scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.004112596, 0.005663693, 0.004772579900000001)
# scipy.sparse.csc_matrix sparse.COO (0.058590405, 0.062796479, 0.0602223605)
# cupy cuda (0.005431101, 0.00612504, 0.0058407055)
# cupy scipy.sparse.coo_matrix (0.059363364, 0.061189875, 0.0601384683)
# cupy cupyx.scipy.sparse.csr_matrix (0.003222193, 0.007743927, 0.0036837286)
# cupy sparse.GCXS (0.088394845, 0.09902657, 0.0917574058)
# cupy numpy (0.005493309, 0.00608333, 0.0057900335)
# cupy cupyx.scipy.sparse.csc_matrix (0.000732672, 0.00088357, 0.0007531936)
# cupy cupyx.scipy.sparse.coo_matrix (0.000793929, 0.001023656, 0.0009950691)
# cupy numpy.matrix (0.005663643, 0.006554626, 0.005937204099999999)
# cupy scipy.sparse.csc_matrix (0.063553939, 0.065274398, 0.0645149235)
# cupy cupy (1.623e-06, 6.723e-06, 5.4837e-06)
# cupy sparse.DOK (0.424369744, 0.476742984, 0.4642118891)
# cupy scipy.sparse.csr_matrix (0.063308452, 0.067783276, 0.0648444757)
# cupy sparse.COO (0.047904729, 0.064339842, 0.052827728)
# sparse.DOK cuda (0.118609366, 0.128670306, 0.1219599234)
# sparse.DOK scipy.sparse.coo_matrix (0.550215433, 0.616769262, 0.56037954)
# sparse.DOK cupyx.scipy.sparse.csr_matrix (0.558555964, 0.569683391, 0.5613383429)
# sparse.DOK sparse.GCXS (0.572588864, 0.604781452, 0.5786749655)
# sparse.DOK numpy (0.121532893, 0.126705192, 0.1239053871)
# sparse.DOK cupyx.scipy.sparse.csc_matrix (0.554923643, 0.568482049, 0.5585472227999999)
# sparse.DOK cupyx.scipy.sparse.coo_matrix (0.549279808, 0.592227467, 0.5575438017000001)
# sparse.DOK numpy.matrix (0.118909808, 0.126583702, 0.12213457929999999)
# sparse.DOK scipy.sparse.csc_matrix (0.549432259, 0.56273468, 0.5572885227000001)
# sparse.DOK cupy (0.121637852, 0.126843476, 0.123253974)
# sparse.DOK sparse.DOK (9.01e-07, 6.752e-06, 5.5684e-06)
# sparse.DOK scipy.sparse.csr_matrix (0.54140727, 0.55929271, 0.5473552376)
# sparse.DOK sparse.COO (0.522827882, 0.530271599, 0.5275931475)
# scipy.sparse.csr_matrix cuda (0.00391525, 0.011599775, 0.0103626944)
# scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.001586705, 0.001764322, 0.0016973715)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (0.001127803, 0.001395412, 0.0013260791)
# scipy.sparse.csr_matrix sparse.GCXS (0.000586665, 0.001104599, 0.0008941603000000001)
# scipy.sparse.csr_matrix numpy (0.003989021, 0.011908632, 0.010360101699999999)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.005534919, 0.005872891, 0.0056814682)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.003802677, 0.004074754, 0.0038897815)
# scipy.sparse.csr_matrix numpy.matrix (0.01028724, 0.011905646, 0.0111408283)
# scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.003690123, 0.004242933, 0.0040305245)
# scipy.sparse.csr_matrix cupy (0.014886841, 0.017188676, 0.0160449881)
# scipy.sparse.csr_matrix sparse.DOK (0.988435204, 1.074312097, 1.0435496957000001)
# scipy.sparse.csr_matrix scipy.sparse.csr_matrix (1.363e-06, 6.563e-06, 5.4937e-06)
# scipy.sparse.csr_matrix sparse.COO (0.009565619, 0.010658165, 0.009789464199999999)
# sparse.COO cuda (0.006996927, 0.008857553, 0.0085781812)
# sparse.COO scipy.sparse.coo_matrix (0.01507553, 0.017798665, 0.0171435471)
# sparse.COO cupyx.scipy.sparse.csr_matrix (0.022663249, 0.025324006, 0.0238861197)
# sparse.COO sparse.GCXS (0.040678546, 0.043002323, 0.0418598023)
# sparse.COO numpy (0.008331213, 0.0087876, 0.008692947199999999)
# sparse.COO cupyx.scipy.sparse.csc_matrix (0.023432632, 0.027519197, 0.0268739308)
# sparse.COO cupyx.scipy.sparse.coo_matrix (0.017825727, 0.02207392, 0.0213925648)
# sparse.COO numpy.matrix (0.008401597, 0.008905434, 0.008783360300000001)
# sparse.COO scipy.sparse.csc_matrix (0.020449272, 0.022908446, 0.021895475100000002)
# sparse.COO cupy (0.010726044, 0.011233558, 0.0111555192)
# sparse.COO sparse.DOK (1.086451912, 1.173631794, 1.1438241113)
# sparse.COO scipy.sparse.csr_matrix (0.016466273, 0.018756185, 0.0179420075)
# sparse.COO sparse.COO (1.062e-06, 6.482e-06, 5.3912e-06)

# %%
names = {
    spc.NUMPY: 'NUMPY',
    spc.NUMPY_MATRIX: 'NUMPY_MATRIX',
    spc.CUDA: 'CUDA',
    spc.CUPY: 'CUPY',
    spc.SPARSE_COO: 'SPARSE_COO',
    spc.SPARSE_GCXS: 'SPARSE_GCXS',
    spc.SPARSE_DOK: 'SPARSE_DOK',
    spc.SCIPY_COO: 'SCIPY_COO',
    spc.SCIPY_CSR: 'SCIPY_CSR',
    spc.SCIPY_CSC: 'SCIPY_CSC',
    spc.CUPY_SCIPY_COO: 'CUPY_SCIPY_COO',
    spc.CUPY_SCIPY_CSR: 'CUPY_SCIPY_CSR',
    spc.CUPY_SCIPY_CSC: 'CUPY_SCIPY_CSC',
}

# %%
for left in sorted(spc.BACKENDS):
    for right in sorted(spc.BACKENDS):
        print(f"    ({names[left]}, {names[right]}): {b[(left, right)][2]},")
# Out:
#     (CUDA, CUDA): 5.7087e-06,
#     (CUDA, CUPY): 0.0033369292000000003,
#     (CUDA, CUPY_SCIPY_COO): 0.0047700987,
#     (CUDA, CUPY_SCIPY_CSC): 0.0044373838,
#     (CUDA, CUPY_SCIPY_CSR): 0.0072124011,
#     (CUDA, NUMPY): 5.3775e-06,
#     (CUDA, NUMPY_MATRIX): 6.19358e-05,
#     (CUDA, SCIPY_COO): 0.0542562901,
#     (CUDA, SCIPY_CSC): 0.0579072341,
#     (CUDA, SCIPY_CSR): 0.0590351847,
#     (CUDA, SPARSE_COO): 0.047494878399999996,
#     (CUDA, SPARSE_DOK): 0.4593789143,
#     (CUDA, SPARSE_GCXS): 0.0869229908,
#     (CUPY, CUDA): 0.0058407055,
#     (CUPY, CUPY): 5.4837e-06,
#     (CUPY, CUPY_SCIPY_COO): 0.0009950691,
#     (CUPY, CUPY_SCIPY_CSC): 0.0007531936,
#     (CUPY, CUPY_SCIPY_CSR): 0.0036837286,
#     (CUPY, NUMPY): 0.0057900335,
#     (CUPY, NUMPY_MATRIX): 0.005937204099999999,
#     (CUPY, SCIPY_COO): 0.0601384683,
#     (CUPY, SCIPY_CSC): 0.0645149235,
#     (CUPY, SCIPY_CSR): 0.0648444757,
#     (CUPY, SPARSE_COO): 0.052827728,
#     (CUPY, SPARSE_DOK): 0.4642118891,
#     (CUPY, SPARSE_GCXS): 0.0917574058,
#     (CUPY_SCIPY_COO, CUDA): 0.0125646027,
#     (CUPY_SCIPY_COO, CUPY): 0.0107726843,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_COO): 5.8401e-06,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSC): 0.0046786442,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSR): 0.0046695442,
#     (CUPY_SCIPY_COO, NUMPY): 0.012788232699999999,
#     (CUPY_SCIPY_COO, NUMPY_MATRIX): 0.012631248199999999,
#     (CUPY_SCIPY_COO, SCIPY_COO): 0.001516897,
#     (CUPY_SCIPY_COO, SCIPY_CSC): 0.0061664394,
#     (CUPY_SCIPY_COO, SCIPY_CSR): 0.0060853895,
#     (CUPY_SCIPY_COO, SPARSE_COO): 0.0098726427,
#     (CUPY_SCIPY_COO, SPARSE_DOK): 1.0562659261,
#     (CUPY_SCIPY_COO, SPARSE_GCXS): 0.0072367965999999995,
#     (CUPY_SCIPY_CSC, CUDA): 0.0133224155,
#     (CUPY_SCIPY_CSC, CUPY): 0.0061948457,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_COO): 0.0010126644,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSC): 5.9003999999999994e-06,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSR): 0.0004962211,
#     (CUPY_SCIPY_CSC, NUMPY): 0.0132182667,
#     (CUPY_SCIPY_CSC, NUMPY_MATRIX): 0.0132212654,
#     (CUPY_SCIPY_CSC, SCIPY_COO): 0.0024322171,
#     (CUPY_SCIPY_CSC, SCIPY_CSC): 0.0008341843000000001,
#     (CUPY_SCIPY_CSC, SCIPY_CSR): 0.0011534851000000001,
#     (CUPY_SCIPY_CSC, SPARSE_COO): 0.057683317399999996,
#     (CUPY_SCIPY_CSC, SPARSE_DOK): 1.1066260407000001,
#     (CUPY_SCIPY_CSC, SPARSE_GCXS): 0.0063828478,
#     (CUPY_SCIPY_CSR, CUDA): 0.0107578735,
#     (CUPY_SCIPY_CSR, CUPY): 0.0061654453,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_COO): 0.0010201825999999999,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSC): 0.0005096146,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSR): 5.4963e-06,
#     (CUPY_SCIPY_CSR, NUMPY): 0.010612198599999999,
#     (CUPY_SCIPY_CSR, NUMPY_MATRIX): 0.0106934284,
#     (CUPY_SCIPY_CSR, SCIPY_COO): 0.0025163781,
#     (CUPY_SCIPY_CSR, SCIPY_CSC): 0.0048487582999999996,
#     (CUPY_SCIPY_CSR, SCIPY_CSR): 0.0007281086999999999,
#     (CUPY_SCIPY_CSR, SPARSE_COO): 0.010840902599999999,
#     (CUPY_SCIPY_CSR, SPARSE_DOK): 1.0502791334,
#     (CUPY_SCIPY_CSR, SPARSE_GCXS): 0.0019567613,
#     (NUMPY, CUDA): 5.6909e-06,
#     (NUMPY, CUPY): 0.0022502914,
#     (NUMPY, CUPY_SCIPY_COO): 0.0046167395,
#     (NUMPY, CUPY_SCIPY_CSC): 0.0043844903,
#     (NUMPY, CUPY_SCIPY_CSR): 0.0071185418,
#     (NUMPY, NUMPY): 5.3913e-06,
#     (NUMPY, NUMPY_MATRIX): 6.228640000000001e-05,
#     (NUMPY, SCIPY_COO): 0.0538344536,
#     (NUMPY, SCIPY_CSC): 0.057908801,
#     (NUMPY, SCIPY_CSR): 0.0587481384,
#     (NUMPY, SPARSE_COO): 0.0475574139,
#     (NUMPY, SPARSE_DOK): 0.4619955832,
#     (NUMPY, SPARSE_GCXS): 0.08869084040000001,
#     (NUMPY_MATRIX, CUDA): 9.0764e-06,
#     (NUMPY_MATRIX, CUPY): 0.0023160705,
#     (NUMPY_MATRIX, CUPY_SCIPY_COO): 0.0046872365,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSC): 0.0044369469000000005,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSR): 0.007215551099999999,
#     (NUMPY_MATRIX, NUMPY): 7.9e-06,
#     (NUMPY_MATRIX, NUMPY_MATRIX): 5.5805e-06,
#     (NUMPY_MATRIX, SCIPY_COO): 0.054201784600000004,
#     (NUMPY_MATRIX, SCIPY_CSC): 0.0582682783,
#     (NUMPY_MATRIX, SCIPY_CSR): 0.0592015605,
#     (NUMPY_MATRIX, SPARSE_COO): 0.0405218495,
#     (NUMPY_MATRIX, SPARSE_DOK): 0.4020413502,
#     (NUMPY_MATRIX, SPARSE_GCXS): 0.080696045,
#     (SCIPY_COO, CUDA): 0.0068673172000000005,
#     (SCIPY_COO, CUPY): 0.0104031465,
#     (SCIPY_COO, CUPY_SCIPY_COO): 0.0029265753,
#     (SCIPY_COO, CUPY_SCIPY_CSC): 0.0083373677,
#     (SCIPY_COO, CUPY_SCIPY_CSR): 0.0075110757000000005,
#     (SCIPY_COO, NUMPY): 0.007202438,
#     (SCIPY_COO, NUMPY_MATRIX): 0.0071584635,
#     (SCIPY_COO, SCIPY_COO): 5.3601000000000006e-06,
#     (SCIPY_COO, SCIPY_CSC): 0.0038445701,
#     (SCIPY_COO, SCIPY_CSR): 0.0051002343,
#     (SCIPY_COO, SPARSE_COO): 0.0005566118000000001,
#     (SCIPY_COO, SPARSE_DOK): 1.0414961782,
#     (SCIPY_COO, SPARSE_GCXS): 0.0051015318,
#     (SCIPY_CSC, CUDA): 0.0087067581,
#     (SCIPY_CSC, CUPY): 0.0122098977,
#     (SCIPY_CSC, CUPY_SCIPY_COO): 0.005907114,
#     (SCIPY_CSC, CUPY_SCIPY_CSC): 0.0017166193999999999,
#     (SCIPY_CSC, CUPY_SCIPY_CSR): 0.0068246185,
#     (SCIPY_CSC, NUMPY): 0.0085353636,
#     (SCIPY_CSC, NUMPY_MATRIX): 0.008607367599999999,
#     (SCIPY_CSC, SCIPY_COO): 0.0036872113,
#     (SCIPY_CSC, SCIPY_CSC): 6.9375e-06,
#     (SCIPY_CSC, SCIPY_CSR): 0.004772579900000001,
#     (SCIPY_CSC, SPARSE_COO): 0.0602223605,
#     (SCIPY_CSC, SPARSE_DOK): 1.0925487128,
#     (SCIPY_CSC, SPARSE_GCXS): 0.0029355244,
#     (SCIPY_CSR, CUDA): 0.0103626944,
#     (SCIPY_CSR, CUPY): 0.0160449881,
#     (SCIPY_CSR, CUPY_SCIPY_COO): 0.0038897815,
#     (SCIPY_CSR, CUPY_SCIPY_CSC): 0.0056814682,
#     (SCIPY_CSR, CUPY_SCIPY_CSR): 0.0013260791,
#     (SCIPY_CSR, NUMPY): 0.010360101699999999,
#     (SCIPY_CSR, NUMPY_MATRIX): 0.0111408283,
#     (SCIPY_CSR, SCIPY_COO): 0.0016973715,
#     (SCIPY_CSR, SCIPY_CSC): 0.0040305245,
#     (SCIPY_CSR, SCIPY_CSR): 5.4937e-06,
#     (SCIPY_CSR, SPARSE_COO): 0.009789464199999999,
#     (SCIPY_CSR, SPARSE_DOK): 1.0435496957000001,
#     (SCIPY_CSR, SPARSE_GCXS): 0.0008941603000000001,
#     (SPARSE_COO, CUDA): 0.0085781812,
#     (SPARSE_COO, CUPY): 0.0111555192,
#     (SPARSE_COO, CUPY_SCIPY_COO): 0.0213925648,
#     (SPARSE_COO, CUPY_SCIPY_CSC): 0.0268739308,
#     (SPARSE_COO, CUPY_SCIPY_CSR): 0.0238861197,
#     (SPARSE_COO, NUMPY): 0.008692947199999999,
#     (SPARSE_COO, NUMPY_MATRIX): 0.008783360300000001,
#     (SPARSE_COO, SCIPY_COO): 0.0171435471,
#     (SPARSE_COO, SCIPY_CSC): 0.021895475100000002,
#     (SPARSE_COO, SCIPY_CSR): 0.0179420075,
#     (SPARSE_COO, SPARSE_COO): 5.3912e-06,
#     (SPARSE_COO, SPARSE_DOK): 1.1438241113,
#     (SPARSE_COO, SPARSE_GCXS): 0.0418598023,
#     (SPARSE_DOK, CUDA): 0.1219599234,
#     (SPARSE_DOK, CUPY): 0.123253974,
#     (SPARSE_DOK, CUPY_SCIPY_COO): 0.5575438017000001,
#     (SPARSE_DOK, CUPY_SCIPY_CSC): 0.5585472227999999,
#     (SPARSE_DOK, CUPY_SCIPY_CSR): 0.5613383429,
#     (SPARSE_DOK, NUMPY): 0.1239053871,
#     (SPARSE_DOK, NUMPY_MATRIX): 0.12213457929999999,
#     (SPARSE_DOK, SCIPY_COO): 0.56037954,
#     (SPARSE_DOK, SCIPY_CSC): 0.5572885227000001,
#     (SPARSE_DOK, SCIPY_CSR): 0.5473552376,
#     (SPARSE_DOK, SPARSE_COO): 0.5275931475,
#     (SPARSE_DOK, SPARSE_DOK): 5.5684e-06,
#     (SPARSE_DOK, SPARSE_GCXS): 0.5786749655,
#     (SPARSE_GCXS, CUDA): 0.0415628543,
#     (SPARSE_GCXS, CUPY): 0.0440102195,
#     (SPARSE_GCXS, CUPY_SCIPY_COO): 0.2519524705,
#     (SPARSE_GCXS, CUPY_SCIPY_CSC): 0.2550338915,
#     (SPARSE_GCXS, CUPY_SCIPY_CSR): 0.250026516,
#     (SPARSE_GCXS, NUMPY): 0.0417246977,
#     (SPARSE_GCXS, NUMPY_MATRIX): 0.0416986575,
#     (SPARSE_GCXS, SCIPY_COO): 0.15432492269999998,
#     (SPARSE_GCXS, SCIPY_CSC): 0.15875735259999998,
#     (SPARSE_GCXS, SCIPY_CSR): 0.1543013657,
#     (SPARSE_GCXS, SPARSE_COO): 0.028974817,
#     (SPARSE_GCXS, SPARSE_DOK): 1.1691816655,
#     (SPARSE_GCXS, SPARSE_GCXS): 5.6678999999999996e-06,
