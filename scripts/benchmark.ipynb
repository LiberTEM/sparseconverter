# %%
import numpy as np
import cupy

import sparseconverter as spc

# %%
b = spc.benchmark_conversions(
    shape=(32, 512, 512),
    dtype=np.float32,
    density=0.1,
    backends=spc.BACKENDS
)
# Out:
# scipy.sparse.coo_matrix scipy.sparse.coo_matrix (1.6e-06, 1.3e-05, 8.16e-06)
# scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.0032439, 0.0043571, 0.00378696)
# scipy.sparse.coo_matrix cuda (0.0048401, 0.0071003, 0.00558513)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.0155205, 0.0271356, 0.01858102)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.0088138, 0.0153338, 0.01082556)
# scipy.sparse.coo_matrix cupy (0.0088139, 0.0171264, 0.01156896)
# scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.0080083, 0.0182293, 0.01044739)
# scipy.sparse.coo_matrix sparse.COO (0.0011318, 0.0015607, 0.00141525)
# scipy.sparse.coo_matrix numpy (0.0048659, 0.0132794, 0.00653755)
# scipy.sparse.coo_matrix sparse.DOK (0.7643482, 0.8682639, 0.80436851)
# scipy.sparse.coo_matrix numpy.matrix (0.0049401, 0.0107264, 0.00598033)
# scipy.sparse.coo_matrix sparse.GCXS (0.0033056, 0.0066266, 0.00408728)
# scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (0.0224215, 0.0250952, 0.02330746)
# scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.0071969, 0.0159147, 0.00909677)
# scipy.sparse.csr_matrix scipy.sparse.csr_matrix (1.3e-06, 1.53e-05, 8.53e-06)
# scipy.sparse.csr_matrix cuda (0.0048683, 0.0098577, 0.00568018)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.0110232, 0.0191186, 0.01258067)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (0.002261, 0.0035367, 0.00259827)
# scipy.sparse.csr_matrix cupy (0.0088134, 0.0123414, 0.0096229)
# scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.0086493, 0.0189479, 0.01083296)
# scipy.sparse.csr_matrix sparse.COO (0.0160069, 0.0251896, 0.01889156)
# scipy.sparse.csr_matrix numpy (0.0048225, 0.0116645, 0.00597631)
# scipy.sparse.csr_matrix sparse.DOK (0.7517229, 0.867282, 0.81050336)
# scipy.sparse.csr_matrix numpy.matrix (0.0048896, 0.0097316, 0.0056923)
# scipy.sparse.csr_matrix sparse.GCXS (2.13e-05, 7.71e-05, 6.774e-05)
# scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.0245173, 0.0361314, 0.02727776)
# cuda scipy.sparse.coo_matrix (0.0619921, 0.0900739, 0.07095157)
# cuda scipy.sparse.csr_matrix (0.0653959, 0.0940877, 0.08185261)
# cuda cuda (1.9e-06, 2.63e-05, 9.52e-06)
# cuda cupyx.scipy.sparse.csc_matrix (0.0199606, 0.1260312, 0.04614623)
# cuda cupyx.scipy.sparse.csr_matrix (0.0201006, 0.0500807, 0.03003148)
# cuda cupy (0.0025682, 0.0050932, 0.0034923)
# cuda scipy.sparse.csc_matrix (0.0699797, 0.0969625, 0.08312156)
# cuda sparse.COO (0.0493102, 0.0633524, 0.05721102)
# cuda numpy (1.4e-06, 2.22e-05, 1.158e-05)
# cuda sparse.DOK (0.4366412, 0.5301924, 0.47822719)
# cuda numpy.matrix (1.65e-05, 0.0002057, 7.85e-05)
# cuda sparse.GCXS (0.0809884, 0.1127846, 0.0926257)
# cuda cupyx.scipy.sparse.coo_matrix (0.0194892, 0.08704, 0.02723361)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.01017, 0.0176322, 0.01265958)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.0274019, 0.0294832, 0.02838422)
# cupyx.scipy.sparse.csc_matrix cuda (0.0121852, 0.0263551, 0.0168752)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (1.6e-06, 1.14e-05, 7.97e-06)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.0121904, 0.0593258, 0.02813724)
# cupyx.scipy.sparse.csc_matrix cupy (0.0446651, 0.0549225, 0.04769173)
# cupyx.scipy.sparse.csc_matrix scipy.sparse.csc_matrix (0.0036178, 0.0073676, 0.00424232)
# cupyx.scipy.sparse.csc_matrix sparse.COO (0.1119043, 0.1550165, 0.12949171)
# cupyx.scipy.sparse.csc_matrix numpy (0.0109849, 0.0150585, 0.01218606)
# cupyx.scipy.sparse.csc_matrix sparse.DOK (0.8495955, 0.9782978, 0.91622471)
# cupyx.scipy.sparse.csc_matrix numpy.matrix (0.0159872, 0.0253216, 0.01833548)
# cupyx.scipy.sparse.csc_matrix sparse.GCXS (0.010125, 0.0119606, 0.01107186)
# cupyx.scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.0208079, 0.022522, 0.02170808)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.coo_matrix (0.0163218, 0.0274704, 0.0187434)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csr_matrix (0.0089074, 0.0100375, 0.00920348)
# cupyx.scipy.sparse.csr_matrix cuda (0.0139842, 0.020579, 0.01544975)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csc_matrix (0.0320973, 0.0399657, 0.03305878)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.csr_matrix (1.3e-06, 1.97e-05, 9.44e-06)
# cupyx.scipy.sparse.csr_matrix cupy (0.0412883, 0.0679787, 0.04449919)
# cupyx.scipy.sparse.csr_matrix scipy.sparse.csc_matrix (0.0119763, 0.0296447, 0.01831002)
# cupyx.scipy.sparse.csr_matrix sparse.COO (0.0233005, 0.0418095, 0.02926526)
# cupyx.scipy.sparse.csr_matrix numpy (0.0079086, 0.0149733, 0.01093995)
# cupyx.scipy.sparse.csr_matrix sparse.DOK (0.7519466, 0.8791915, 0.81829223)
# cupyx.scipy.sparse.csr_matrix numpy.matrix (0.0138849, 0.0224964, 0.01565349)
# cupyx.scipy.sparse.csr_matrix sparse.GCXS (0.0090975, 0.0104932, 0.00943145)
# cupyx.scipy.sparse.csr_matrix cupyx.scipy.sparse.coo_matrix (0.0175565, 0.0199174, 0.01864054)
# cupy scipy.sparse.coo_matrix (0.1054044, 0.1415327, 0.12031532)
# cupy scipy.sparse.csr_matrix (0.107913, 0.1239084, 0.11456013)
# cupy cuda (0.0410462, 0.0415445, 0.04123289)
# cupy cupyx.scipy.sparse.csc_matrix (0.0054466, 0.0645371, 0.01339789)
# cupy cupyx.scipy.sparse.csr_matrix (0.008854, 0.0440956, 0.02236629)
# cupy cupy (5.6e-06, 2.16e-05, 9.94e-06)
# cupy scipy.sparse.csc_matrix (0.0847326, 0.1425717, 0.1171756)
# cupy sparse.COO (0.0920217, 0.112749, 0.1018334)
# cupy numpy (0.0409779, 0.0414948, 0.04115815)
# cupy sparse.DOK (0.4902668, 0.5852267, 0.52614732)
# cupy numpy.matrix (0.0411923, 0.0417698, 0.04145609)
# cupy sparse.GCXS (0.1341287, 0.1482737, 0.14133173)
# cupy cupyx.scipy.sparse.coo_matrix (0.0090231, 0.0808691, 0.02365191)
# scipy.sparse.csc_matrix scipy.sparse.coo_matrix (0.0087284, 0.0199679, 0.0104994)
# scipy.sparse.csc_matrix scipy.sparse.csr_matrix (0.0050642, 0.0116704, 0.00648227)
# scipy.sparse.csc_matrix cuda (0.005153, 0.0069901, 0.00567477)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csc_matrix (0.0026869, 0.0085457, 0.00359595)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.csr_matrix (0.0075727, 0.0127925, 0.00917898)
# scipy.sparse.csc_matrix cupy (0.0089875, 0.0232322, 0.01150378)
# scipy.sparse.csc_matrix scipy.sparse.csc_matrix (1.5e-06, 1.03e-05, 8.02e-06)
# scipy.sparse.csc_matrix sparse.COO (0.1067852, 0.1488865, 0.12335432)
# scipy.sparse.csc_matrix numpy (0.0051571, 0.0102895, 0.00634705)
# scipy.sparse.csc_matrix sparse.DOK (0.8318762, 0.958307, 0.91889736)
# scipy.sparse.csc_matrix numpy.matrix (0.0052476, 0.0069461, 0.00548948)
# scipy.sparse.csc_matrix sparse.GCXS (1.92e-05, 0.0001264, 7.436e-05)
# scipy.sparse.csc_matrix cupyx.scipy.sparse.coo_matrix (0.0255331, 0.0345435, 0.02839993)
# sparse.COO scipy.sparse.coo_matrix (0.0183684, 0.0286581, 0.02236511)
# sparse.COO scipy.sparse.csr_matrix (0.0196708, 0.0296038, 0.02309729)
# sparse.COO cuda (0.0133906, 0.0226234, 0.01559104)
# sparse.COO cupyx.scipy.sparse.csc_matrix (0.0338751, 0.045334, 0.03912978)
# sparse.COO cupyx.scipy.sparse.csr_matrix (0.027761, 0.0394257, 0.03297643)
# sparse.COO cupy (0.0169952, 0.0294447, 0.02050667)
# sparse.COO scipy.sparse.csc_matrix (0.0290839, 0.0397643, 0.03321482)
# sparse.COO sparse.COO (3.5e-06, 1.86e-05, 9.63e-06)
# sparse.COO numpy (0.0131158, 0.0345246, 0.01665228)
# sparse.COO sparse.DOK (0.8436707, 0.9138669, 0.86456496)
# sparse.COO numpy.matrix (0.0137721, 0.0220768, 0.01669986)
# sparse.COO sparse.GCXS (0.03299, 0.0437467, 0.03934677)
# sparse.COO cupyx.scipy.sparse.coo_matrix (0.0437154, 0.0511147, 0.04699705)
# numpy scipy.sparse.coo_matrix (0.0715482, 0.0841548, 0.07762542)
# numpy scipy.sparse.csr_matrix (0.069796, 0.1064467, 0.07794126)
# numpy cuda (1.5e-06, 1.55e-05, 8.96e-06)
# numpy cupyx.scipy.sparse.csc_matrix (0.0190473, 0.1174953, 0.03194446)
# numpy cupyx.scipy.sparse.csr_matrix (0.0222623, 0.0629003, 0.02707654)
# numpy cupy (0.0025969, 0.0043214, 0.00304166)
# numpy scipy.sparse.csc_matrix (0.070763, 0.1043254, 0.08492988)
# numpy sparse.COO (0.0494163, 0.0686865, 0.05836581)
# numpy numpy (1.4e-06, 1.36e-05, 8.62e-06)
# numpy sparse.DOK (0.4299139, 0.5162927, 0.48218718)
# numpy numpy.matrix (1.72e-05, 0.0001572, 8.378e-05)
# numpy sparse.GCXS (0.0810031, 0.119379, 0.09733027)
# numpy cupyx.scipy.sparse.coo_matrix (0.0193573, 0.132532, 0.03111887)
# sparse.DOK scipy.sparse.coo_matrix (0.4367045, 0.5039124, 0.47121842)
# sparse.DOK scipy.sparse.csr_matrix (0.4170684, 0.4968299, 0.45030841)
# sparse.DOK cuda (0.1016017, 0.1476235, 0.11838129)
# sparse.DOK cupyx.scipy.sparse.csc_matrix (0.4374675, 0.5051707, 0.48294454)
# sparse.DOK cupyx.scipy.sparse.csr_matrix (0.4496194, 0.5274403, 0.48472009)
# sparse.DOK cupy (0.1101136, 0.1419762, 0.12566395)
# sparse.DOK scipy.sparse.csc_matrix (0.4269613, 0.4955499, 0.45739357)
# sparse.DOK sparse.COO (0.3951186, 0.4906623, 0.43964837)
# sparse.DOK numpy (0.1128447, 0.1510091, 0.12760996)
# sparse.DOK sparse.DOK (1.4e-06, 1.24e-05, 8.7e-06)
# sparse.DOK numpy.matrix (0.113278, 0.1470626, 0.12691516)
# sparse.DOK sparse.GCXS (0.4327401, 0.54029, 0.4815116)
# sparse.DOK cupyx.scipy.sparse.coo_matrix (0.433295, 0.491236, 0.46361514)
# numpy.matrix scipy.sparse.coo_matrix (0.063462, 0.09604, 0.07374739)
# numpy.matrix scipy.sparse.csr_matrix (0.0656115, 0.0883418, 0.07748237)
# numpy.matrix cuda (2.1e-06, 1.8e-05, 1.267e-05)
# numpy.matrix cupyx.scipy.sparse.csc_matrix (0.0190368, 0.1369284, 0.03340842)
# numpy.matrix cupyx.scipy.sparse.csr_matrix (0.0203637, 0.0621056, 0.02498352)
# numpy.matrix cupy (0.0026028, 0.004467, 0.00304186)
# numpy.matrix scipy.sparse.csc_matrix (0.0710121, 0.1020007, 0.08479951)
# numpy.matrix sparse.COO (0.0439583, 0.0748198, 0.05546078)
# numpy.matrix numpy (2e-06, 2.4e-05, 1.266e-05)
# numpy.matrix sparse.DOK (0.3700706, 0.467839, 0.42378837)
# numpy.matrix numpy.matrix (1.5e-06, 1.66e-05, 9.09e-06)
# numpy.matrix sparse.GCXS (0.0738689, 0.09487, 0.08626198)
# numpy.matrix cupyx.scipy.sparse.coo_matrix (0.0192609, 0.1318371, 0.03103336)
# sparse.GCXS scipy.sparse.coo_matrix (0.4081273, 0.4663817, 0.44208745)
# sparse.GCXS scipy.sparse.csr_matrix (0.4039746, 0.4663899, 0.43229283)
# sparse.GCXS cuda (0.0460064, 0.0766742, 0.05721252)
# sparse.GCXS cupyx.scipy.sparse.csc_matrix (0.4666412, 0.5538461, 0.51329979)
# sparse.GCXS cupyx.scipy.sparse.csr_matrix (0.4699889, 0.5613313, 0.51411286)
# sparse.GCXS cupy (0.049757, 0.0722601, 0.05968288)
# sparse.GCXS scipy.sparse.csc_matrix (0.4017124, 0.473233, 0.43770924)
# sparse.GCXS sparse.COO (0.0320188, 0.0429558, 0.03560626)
# sparse.GCXS numpy (0.0459424, 0.0723855, 0.05773925)
# sparse.GCXS sparse.DOK (0.8214997, 0.9570738, 0.88085017)
# sparse.GCXS numpy.matrix (0.0462764, 0.0626621, 0.05410605)
# sparse.GCXS sparse.GCXS (1.3e-06, 0.0001178, 2.003e-05)
# sparse.GCXS cupyx.scipy.sparse.coo_matrix (0.5067416, 0.5901778, 0.54629951)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.coo_matrix (0.0150067, 0.02256, 0.01752424)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csr_matrix (0.0471993, 0.0519749, 0.04840724)
# cupyx.scipy.sparse.coo_matrix cuda (0.0114361, 0.0214886, 0.01391734)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csc_matrix (0.031287, 0.0446698, 0.03534527)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.csr_matrix (0.0326789, 0.0476325, 0.03556132)
# cupyx.scipy.sparse.coo_matrix cupy (0.0826512, 0.1069914, 0.08673978)
# cupyx.scipy.sparse.coo_matrix scipy.sparse.csc_matrix (0.0470007, 0.0522235, 0.04930567)
# cupyx.scipy.sparse.coo_matrix sparse.COO (0.0189948, 0.0303182, 0.02267181)
# cupyx.scipy.sparse.coo_matrix numpy (0.0114711, 0.0181594, 0.01307202)
# cupyx.scipy.sparse.coo_matrix sparse.DOK (0.7637674, 0.8631526, 0.81842092)
# cupyx.scipy.sparse.coo_matrix numpy.matrix (0.0206633, 0.0306326, 0.02308691)
# cupyx.scipy.sparse.coo_matrix sparse.GCXS (0.0475345, 0.0499106, 0.04826163)
# cupyx.scipy.sparse.coo_matrix cupyx.scipy.sparse.coo_matrix (1.4e-06, 1.83e-05, 9.15e-06)

# %%
names = {
    spc.NUMPY: 'NUMPY',
    spc.NUMPY_MATRIX: 'NUMPY_MATRIX',
    spc.CUDA: 'CUDA',
    spc.CUPY: 'CUPY',
    spc.SPARSE_COO: 'SPARSE_COO',
    spc.SPARSE_GCXS: 'SPARSE_GCXS',
    spc.SPARSE_DOK: 'SPARSE_DOK',
    spc.SCIPY_COO: 'SCIPY_COO',
    spc.SCIPY_CSR: 'SCIPY_CSR',
    spc.SCIPY_CSC: 'SCIPY_CSC',
    spc.CUPY_SCIPY_COO: 'CUPY_SCIPY_COO',
    spc.CUPY_SCIPY_CSR: 'CUPY_SCIPY_CSR',
    spc.CUPY_SCIPY_CSC: 'CUPY_SCIPY_CSC',
}

# %%
for left in sorted(spc.BACKENDS):
    for right in sorted(spc.BACKENDS):
        print(f"    ({names[left]}, {names[right]}): {b[(left, right)][2]},")
# Out:
#     (CUDA, CUDA): 9.52e-06,
#     (CUDA, CUPY): 0.0034923,
#     (CUDA, CUPY_SCIPY_COO): 0.02723361,
#     (CUDA, CUPY_SCIPY_CSC): 0.04614623,
#     (CUDA, CUPY_SCIPY_CSR): 0.03003148,
#     (CUDA, NUMPY): 1.158e-05,
#     (CUDA, NUMPY_MATRIX): 7.85e-05,
#     (CUDA, SCIPY_COO): 0.07095157,
#     (CUDA, SCIPY_CSC): 0.08312156,
#     (CUDA, SCIPY_CSR): 0.08185261,
#     (CUDA, SPARSE_COO): 0.05721102,
#     (CUDA, SPARSE_DOK): 0.47822719,
#     (CUDA, SPARSE_GCXS): 0.0926257,
#     (CUPY, CUDA): 0.04123289,
#     (CUPY, CUPY): 9.94e-06,
#     (CUPY, CUPY_SCIPY_COO): 0.02365191,
#     (CUPY, CUPY_SCIPY_CSC): 0.01339789,
#     (CUPY, CUPY_SCIPY_CSR): 0.02236629,
#     (CUPY, NUMPY): 0.04115815,
#     (CUPY, NUMPY_MATRIX): 0.04145609,
#     (CUPY, SCIPY_COO): 0.12031532,
#     (CUPY, SCIPY_CSC): 0.1171756,
#     (CUPY, SCIPY_CSR): 0.11456013,
#     (CUPY, SPARSE_COO): 0.1018334,
#     (CUPY, SPARSE_DOK): 0.52614732,
#     (CUPY, SPARSE_GCXS): 0.14133173,
#     (CUPY_SCIPY_COO, CUDA): 0.01391734,
#     (CUPY_SCIPY_COO, CUPY): 0.08673978,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_COO): 9.15e-06,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSC): 0.03534527,
#     (CUPY_SCIPY_COO, CUPY_SCIPY_CSR): 0.03556132,
#     (CUPY_SCIPY_COO, NUMPY): 0.01307202,
#     (CUPY_SCIPY_COO, NUMPY_MATRIX): 0.02308691,
#     (CUPY_SCIPY_COO, SCIPY_COO): 0.01752424,
#     (CUPY_SCIPY_COO, SCIPY_CSC): 0.04930567,
#     (CUPY_SCIPY_COO, SCIPY_CSR): 0.04840724,
#     (CUPY_SCIPY_COO, SPARSE_COO): 0.02267181,
#     (CUPY_SCIPY_COO, SPARSE_DOK): 0.81842092,
#     (CUPY_SCIPY_COO, SPARSE_GCXS): 0.04826163,
#     (CUPY_SCIPY_CSC, CUDA): 0.0168752,
#     (CUPY_SCIPY_CSC, CUPY): 0.04769173,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_COO): 0.02170808,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSC): 7.97e-06,
#     (CUPY_SCIPY_CSC, CUPY_SCIPY_CSR): 0.02813724,
#     (CUPY_SCIPY_CSC, NUMPY): 0.01218606,
#     (CUPY_SCIPY_CSC, NUMPY_MATRIX): 0.01833548,
#     (CUPY_SCIPY_CSC, SCIPY_COO): 0.01265958,
#     (CUPY_SCIPY_CSC, SCIPY_CSC): 0.00424232,
#     (CUPY_SCIPY_CSC, SCIPY_CSR): 0.02838422,
#     (CUPY_SCIPY_CSC, SPARSE_COO): 0.12949171,
#     (CUPY_SCIPY_CSC, SPARSE_DOK): 0.91622471,
#     (CUPY_SCIPY_CSC, SPARSE_GCXS): 0.01107186,
#     (CUPY_SCIPY_CSR, CUDA): 0.01544975,
#     (CUPY_SCIPY_CSR, CUPY): 0.04449919,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_COO): 0.01864054,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSC): 0.03305878,
#     (CUPY_SCIPY_CSR, CUPY_SCIPY_CSR): 9.44e-06,
#     (CUPY_SCIPY_CSR, NUMPY): 0.01093995,
#     (CUPY_SCIPY_CSR, NUMPY_MATRIX): 0.01565349,
#     (CUPY_SCIPY_CSR, SCIPY_COO): 0.0187434,
#     (CUPY_SCIPY_CSR, SCIPY_CSC): 0.01831002,
#     (CUPY_SCIPY_CSR, SCIPY_CSR): 0.00920348,
#     (CUPY_SCIPY_CSR, SPARSE_COO): 0.02926526,
#     (CUPY_SCIPY_CSR, SPARSE_DOK): 0.81829223,
#     (CUPY_SCIPY_CSR, SPARSE_GCXS): 0.00943145,
#     (NUMPY, CUDA): 8.96e-06,
#     (NUMPY, CUPY): 0.00304166,
#     (NUMPY, CUPY_SCIPY_COO): 0.03111887,
#     (NUMPY, CUPY_SCIPY_CSC): 0.03194446,
#     (NUMPY, CUPY_SCIPY_CSR): 0.02707654,
#     (NUMPY, NUMPY): 8.62e-06,
#     (NUMPY, NUMPY_MATRIX): 8.378e-05,
#     (NUMPY, SCIPY_COO): 0.07762542,
#     (NUMPY, SCIPY_CSC): 0.08492988,
#     (NUMPY, SCIPY_CSR): 0.07794126,
#     (NUMPY, SPARSE_COO): 0.05836581,
#     (NUMPY, SPARSE_DOK): 0.48218718,
#     (NUMPY, SPARSE_GCXS): 0.09733027,
#     (NUMPY_MATRIX, CUDA): 1.267e-05,
#     (NUMPY_MATRIX, CUPY): 0.00304186,
#     (NUMPY_MATRIX, CUPY_SCIPY_COO): 0.03103336,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSC): 0.03340842,
#     (NUMPY_MATRIX, CUPY_SCIPY_CSR): 0.02498352,
#     (NUMPY_MATRIX, NUMPY): 1.266e-05,
#     (NUMPY_MATRIX, NUMPY_MATRIX): 9.09e-06,
#     (NUMPY_MATRIX, SCIPY_COO): 0.07374739,
#     (NUMPY_MATRIX, SCIPY_CSC): 0.08479951,
#     (NUMPY_MATRIX, SCIPY_CSR): 0.07748237,
#     (NUMPY_MATRIX, SPARSE_COO): 0.05546078,
#     (NUMPY_MATRIX, SPARSE_DOK): 0.42378837,
#     (NUMPY_MATRIX, SPARSE_GCXS): 0.08626198,
#     (SCIPY_COO, CUDA): 0.00558513,
#     (SCIPY_COO, CUPY): 0.01156896,
#     (SCIPY_COO, CUPY_SCIPY_COO): 0.02330746,
#     (SCIPY_COO, CUPY_SCIPY_CSC): 0.01858102,
#     (SCIPY_COO, CUPY_SCIPY_CSR): 0.01082556,
#     (SCIPY_COO, NUMPY): 0.00653755,
#     (SCIPY_COO, NUMPY_MATRIX): 0.00598033,
#     (SCIPY_COO, SCIPY_COO): 8.16e-06,
#     (SCIPY_COO, SCIPY_CSC): 0.01044739,
#     (SCIPY_COO, SCIPY_CSR): 0.00378696,
#     (SCIPY_COO, SPARSE_COO): 0.00141525,
#     (SCIPY_COO, SPARSE_DOK): 0.80436851,
#     (SCIPY_COO, SPARSE_GCXS): 0.00408728,
#     (SCIPY_CSC, CUDA): 0.00567477,
#     (SCIPY_CSC, CUPY): 0.01150378,
#     (SCIPY_CSC, CUPY_SCIPY_COO): 0.02839993,
#     (SCIPY_CSC, CUPY_SCIPY_CSC): 0.00359595,
#     (SCIPY_CSC, CUPY_SCIPY_CSR): 0.00917898,
#     (SCIPY_CSC, NUMPY): 0.00634705,
#     (SCIPY_CSC, NUMPY_MATRIX): 0.00548948,
#     (SCIPY_CSC, SCIPY_COO): 0.0104994,
#     (SCIPY_CSC, SCIPY_CSC): 8.02e-06,
#     (SCIPY_CSC, SCIPY_CSR): 0.00648227,
#     (SCIPY_CSC, SPARSE_COO): 0.12335432,
#     (SCIPY_CSC, SPARSE_DOK): 0.91889736,
#     (SCIPY_CSC, SPARSE_GCXS): 7.436e-05,
#     (SCIPY_CSR, CUDA): 0.00568018,
#     (SCIPY_CSR, CUPY): 0.0096229,
#     (SCIPY_CSR, CUPY_SCIPY_COO): 0.02727776,
#     (SCIPY_CSR, CUPY_SCIPY_CSC): 0.01258067,
#     (SCIPY_CSR, CUPY_SCIPY_CSR): 0.00259827,
#     (SCIPY_CSR, NUMPY): 0.00597631,
#     (SCIPY_CSR, NUMPY_MATRIX): 0.0056923,
#     (SCIPY_CSR, SCIPY_COO): 0.00909677,
#     (SCIPY_CSR, SCIPY_CSC): 0.01083296,
#     (SCIPY_CSR, SCIPY_CSR): 8.53e-06,
#     (SCIPY_CSR, SPARSE_COO): 0.01889156,
#     (SCIPY_CSR, SPARSE_DOK): 0.81050336,
#     (SCIPY_CSR, SPARSE_GCXS): 6.774e-05,
#     (SPARSE_COO, CUDA): 0.01559104,
#     (SPARSE_COO, CUPY): 0.02050667,
#     (SPARSE_COO, CUPY_SCIPY_COO): 0.04699705,
#     (SPARSE_COO, CUPY_SCIPY_CSC): 0.03912978,
#     (SPARSE_COO, CUPY_SCIPY_CSR): 0.03297643,
#     (SPARSE_COO, NUMPY): 0.01665228,
#     (SPARSE_COO, NUMPY_MATRIX): 0.01669986,
#     (SPARSE_COO, SCIPY_COO): 0.02236511,
#     (SPARSE_COO, SCIPY_CSC): 0.03321482,
#     (SPARSE_COO, SCIPY_CSR): 0.02309729,
#     (SPARSE_COO, SPARSE_COO): 9.63e-06,
#     (SPARSE_COO, SPARSE_DOK): 0.86456496,
#     (SPARSE_COO, SPARSE_GCXS): 0.03934677,
#     (SPARSE_DOK, CUDA): 0.11838129,
#     (SPARSE_DOK, CUPY): 0.12566395,
#     (SPARSE_DOK, CUPY_SCIPY_COO): 0.46361514,
#     (SPARSE_DOK, CUPY_SCIPY_CSC): 0.48294454,
#     (SPARSE_DOK, CUPY_SCIPY_CSR): 0.48472009,
#     (SPARSE_DOK, NUMPY): 0.12760996,
#     (SPARSE_DOK, NUMPY_MATRIX): 0.12691516,
#     (SPARSE_DOK, SCIPY_COO): 0.47121842,
#     (SPARSE_DOK, SCIPY_CSC): 0.45739357,
#     (SPARSE_DOK, SCIPY_CSR): 0.45030841,
#     (SPARSE_DOK, SPARSE_COO): 0.43964837,
#     (SPARSE_DOK, SPARSE_DOK): 8.7e-06,
#     (SPARSE_DOK, SPARSE_GCXS): 0.4815116,
#     (SPARSE_GCXS, CUDA): 0.05721252,
#     (SPARSE_GCXS, CUPY): 0.05968288,
#     (SPARSE_GCXS, CUPY_SCIPY_COO): 0.54629951,
#     (SPARSE_GCXS, CUPY_SCIPY_CSC): 0.51329979,
#     (SPARSE_GCXS, CUPY_SCIPY_CSR): 0.51411286,
#     (SPARSE_GCXS, NUMPY): 0.05773925,
#     (SPARSE_GCXS, NUMPY_MATRIX): 0.05410605,
#     (SPARSE_GCXS, SCIPY_COO): 0.44208745,
#     (SPARSE_GCXS, SCIPY_CSC): 0.43770924,
#     (SPARSE_GCXS, SCIPY_CSR): 0.43229283,
#     (SPARSE_GCXS, SPARSE_COO): 0.03560626,
#     (SPARSE_GCXS, SPARSE_DOK): 0.88085017,
#     (SPARSE_GCXS, SPARSE_GCXS): 2.003e-05,
